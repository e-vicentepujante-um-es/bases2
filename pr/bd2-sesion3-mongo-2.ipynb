# %% [markdown]
# ## NoSQL (MongoDB) (sesión 2)

# %% [markdown]
# ## Introducción

# %% [markdown]
# ![MongoDB](https://webassets.mongodb.com/_com_assets/cms/MongoDB_Logo_FullColorBlack_RGB-4td3yuxzjs.png)
#
# Esta hoja muestra cómo acceder a bases de datos MongoDB y también a conectar la salida con Jupyter. Se puede utilizar el *shell* propio de MongoDB en el contenedor usando el programa `mongo`. La diferencia es que ese programa espera código Javascript y aquí trabajaremos con Python.

# %%
RunningInCOLAB: bool = 'google.colab' in str(get_ipython()) if hasattr(__builtins__,'__IPYTHON__') else False

# %%
if not RunningInCOLAB:
    # !sudo apt-get update -qq
    # !sudo apt-get install -y -qq gpg p7zip

# %% [markdown]
# ## Instalación inicial de MongoDB (sólo necesaria en Google Colab)

# %%
if RunningInCOLAB:
  # !wget -q https://raw.githubusercontent.com/dsevilla/bdge/refs/heads/24-25/addendum/mongo-utils/run-mongo-local.sh
  # !bash run-mongo-local.sh
# Out:
# Adding system user `mongodb' (UID 104) ...
# Adding new user `mongodb' (UID 104) with group `nogroup' ...
# Not creating home directory `/home/mongodb'.
# Adding group `mongodb' (GID 107) ...
# Done.
# Adding user `mongodb' to group `mongodb' ...
# Adding user mongodb to group mongodb
# Done.
# deb [ arch=amd64,arm64 ] https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/8.0 multiverse
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 10.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dialog.
# (Reading database ... 124947 files and directories currently installed.)
# Preparing to unpack .../0-dialog_1.3-20211214-1_amd64.deb ...
# Unpacking dialog (1.3-20211214-1) ...
# Selecting previously unselected package mongodb-database-tools.
# Preparing to unpack .../1-mongodb-database-tools_100.11.0_amd64.deb ...
# Unpacking mongodb-database-tools (100.11.0) ...
# Selecting previously unselected package mongodb-mongosh.
# Preparing to unpack .../2-mongodb-mongosh_2.4.2_amd64.deb ...
# Unpacking mongodb-mongosh (2.4.2) ...
# Selecting previously unselected package mongodb-org-shell.
# Preparing to unpack .../3-mongodb-org-shell_8.0.5_amd64.deb ...
# Unpacking mongodb-org-shell (8.0.5) ...
# Selecting previously unselected package mongodb-org-server.
# Preparing to unpack .../4-mongodb-org-server_8.0.5_amd64.deb ...
# Unpacking mongodb-org-server (8.0.5) ...
# Selecting previously unselected package mongodb-org-mongos.
# Preparing to unpack .../5-mongodb-org-mongos_8.0.5_amd64.deb ...
# Unpacking mongodb-org-mongos (8.0.5) ...
# Selecting previously unselected package mongodb-org-database-tools-extra.
# Preparing to unpack .../6-mongodb-org-database-tools-extra_8.0.5_amd64.deb ...
# Unpacking mongodb-org-database-tools-extra (8.0.5) ...
# Selecting previously unselected package mongodb-org-database.
# Preparing to unpack .../7-mongodb-org-database_8.0.5_amd64.deb ...
# Unpacking mongodb-org-database (8.0.5) ...
# Selecting previously unselected package mongodb-org-tools.
# Preparing to unpack .../8-mongodb-org-tools_8.0.5_amd64.deb ...
# Unpacking mongodb-org-tools (8.0.5) ...
# Selecting previously unselected package mongodb-org.
# Preparing to unpack .../9-mongodb-org_8.0.5_amd64.deb ...
# Unpacking mongodb-org (8.0.5) ...
# Setting up mongodb-mongosh (2.4.2) ...
# Setting up mongodb-org-server (8.0.5) ...
# Setting up mongodb-org-shell (8.0.5) ...
# Setting up dialog (1.3-20211214-1) ...
# Setting up mongodb-database-tools (100.11.0) ...
# Setting up mongodb-org-mongos (8.0.5) ...
# Setting up mongodb-org-database-tools-extra (8.0.5) ...
# Setting up mongodb-org-database (8.0.5) ...
# Setting up mongodb-org-tools (8.0.5) ...
# Setting up mongodb-org (8.0.5) ...
# Processing triggers for man-db (2.10.2-1) ...
# about to fork child process, waiting until server is ready for connections.
# forked process: 1625
# child process started successfully, parent exiting
# db version v8.0.5
# Build Info: {
#     "version": "8.0.5",
#     "gitVersion": "cb9e2e5e552ee39dea1e39d7859336456d0c9820",
#     "openSSLVersion": "OpenSSL 3.0.2 15 Mar 2022",
#     "modules": [],
#     "allocator": "tcmalloc-google",
#     "environment": {
#         "distmod": "ubuntu2204",
#         "distarch": "x86_64",
#         "target_arch": "x86_64"
#     }
# }

# %% [markdown]
# ## Descarga de los datos en formato CSV

# %% [markdown]
#  - Formato: 7zipped
#  - Ficheros:
#    - **Comments**.csv
#        - Id
#        - PostId
#        - Score
#        - Text, e.g.: "@Stu Thompson: Seems possible to me - why not try it?"
#        - CreationDate, e.g.:"2008-09-06T08:07:10.730"
#        - UserId
#    - **Posts**.csv
#        - Id
#        - PostTypeId
#           - 1: Question
#           - 2: Answer
#        - ParentID (only present if PostTypeId is 2)
#        - AcceptedAnswerId (only present if PostTypeId is 1)
#        - CreationDate
#        - Score
#        - ViewCount
#        - Body
#        - OwnerUserId
#        - LastEditorUserId
#        - LastEditorDisplayName="Jeff Atwood"
#        - LastEditDate="2009-03-05T22:28:34.823"
#        - LastActivityDate="2009-03-11T12:51:01.480"
#        - CommunityOwnedDate="2009-03-11T12:51:01.480"
#        - ClosedDate="2009-03-11T12:51:01.480"
#        - Title=
#        - Tags=
#        - AnswerCount
#        - CommentCount
#        - FavoriteCount
#    - **Tags**.csv
#     - Id
#     - Count
#     - ExcerptPostId
#     - TagName
#     - WikiPostId
#    - **Users**.csv
#      - Id
#      - Reputation
#      - CreationDate
#      - DisplayName
#      - EmailHash
#      - LastAccessDate
#      - WebsiteUrl
#      - Location
#      - Age
#      - AboutMe
#      - Views
#      - UpVotes
#      - DownVotes
#    - **Votes**.csv
#      - Id
#      - PostId
#      - VoteTypeId
#         - ` 1`: AcceptedByOriginator
#         - ` 2`: UpMod
#         - ` 3`: DownMod
#         - ` 4`: Offensive
#         - ` 5`: Favorite - if VoteTypeId = 5 UserId will be populated
#         - ` 6`: Close
#         - ` 7`: Reopen
#         - ` 8`: BountyStart
#         - ` 9`: BountyClose
#         - `10`: Deletion
#         - `11`: Undeletion
#         - `12`: Spam
#         - `13`: InformModerator
#      - CreationDate
#      - UserId (only for VoteTypeId 5)
#      - BountyAmount (only for VoteTypeId 9)

# %%
# !wget https://github.com/dsevilla/bd2-data/raw/main/es.stackoverflow/es.stackoverflow.csv.7z.001 -O - > es.stackoverflow.csv.7z
# !wget https://github.com/dsevilla/bd2-data/raw/main/es.stackoverflow/es.stackoverflow.csv.7z.002 -O - >> es.stackoverflow.csv.7z
# Out:
# --2025-03-06 18:15:59--  https://github.com/dsevilla/bd2-data/raw/main/es.stackoverflow/es.stackoverflow.csv.7z.001
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dsevilla/bd2-data/main/es.stackoverflow/es.stackoverflow.csv.7z.001 [following]
# --2025-03-06 18:15:59--  https://raw.githubusercontent.com/dsevilla/bd2-data/main/es.stackoverflow/es.stackoverflow.csv.7z.001
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104857600 (100M) [application/octet-stream]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>] 100.00M   344MB/s    in 0.3s
#
# 2025-03-06 18:16:02 (344 MB/s) - written to stdout [104857600/104857600]
#
# --2025-03-06 18:16:02--  https://github.com/dsevilla/bd2-data/raw/main/es.stackoverflow/es.stackoverflow.csv.7z.002
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dsevilla/bd2-data/main/es.stackoverflow/es.stackoverflow.csv.7z.002 [following]
# --2025-03-06 18:16:03--  https://raw.githubusercontent.com/dsevilla/bd2-data/main/es.stackoverflow/es.stackoverflow.csv.7z.002
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95599938 (91M) [application/octet-stream]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]  91.17M   167MB/s    in 0.5s
#
# 2025-03-06 18:16:06 (167 MB/s) - written to stdout [95599938/95599938]

# %%
!7zr x -aoa es.stackoverflow.csv.7z
# !rm es.stackoverflow.csv.7z
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 200457538 bytes (192 MiB)
#
# Extracting archive: es.stackoverflow.csv.7z
# --
# Path = es.stackoverflow.csv.7z
# Type = 7z
# Physical Size = 200457538
# Headers Size = 248
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Files: 5
# Size:       1044736301
# Compressed: 200457538

# %%
# !head Users.csv
# Out:
# Id,AboutMe,AccountId,CreationDate,DisplayName,DownVotes,LastAccessDate,Location,Reputation,UpVotes,Views,WebsiteUrl
# -1,"<p>Hola, no soy una persona real.</p><br/><br/><p>¡Soy un proceso que ayuda a mantener el sitio limpio!</p><br/><br/><p>Hago cosas como:</p><br/><br/><ul><br/><li>Dar empujoncitos a preguntas antiguas sin respuesta aproximadamente cada hora, para que atraigan algo de atención.</li><br/><li>Tener la propiedad de las preguntas y respuestas wiki para que nadie se lleve reputación por ellas</li><br/><li>Recibir la propiedad de los votos negativos en las publicaciones de spam o dañinas que son borradas permanentemente</li><br/><li>Tener la propiedad de las ediciones sugeridas por usuarios anónimos</li><br/><li><a href=""http://meta.stackoverflow.com/a/92006"">Quitar preguntas abandonadas</a></li><br/></ul><br/>",-1,2015-10-26T21:36:24.767,Comunidad,22504,2015-10-26T21:36:24.767,en la granja de servidores,1,10211,2516,
# 1,"<p>Dev #2 who helped create Stack Overflow currently working at Microsoft. I love all people willing to share their knowledge. Without community we are nothing.</p><br/><p>Find me on:</p><br/><p><a href=""http://www.twitter.com/SuperDalgas"" rel=""nofollow noreferrer"">Twitter</a><br/><br><br><br/><a href=""http://blog.stackoverflow.com/2009/05/welcome-stack-overflow-valued-associate-00003/"">Stack Overflow Valued Associate #00003</a></p><br/>",2,2015-10-26T22:50:12.710,Geoff Dalgas,0,2021-01-05T19:45:26.807,"Corvallis, OR",101,0,2917,http://stackoverflow.com
# 2,"<p>developer, techie, nerd.... ex-DBRE at Stack Overflow, previously a Community Manager for Stack Overflow.  When I'm not at my desk, I do CrossFit and run (a lot).</p><br/>",188123,2015-10-26T22:51:07.007,Taryn,0,2020-08-18T17:39:10.693,Arizona,101,0,109,https://tarynpivots.com
# 3,"<p>Topics you might be interested in reading about:</p><br/><ul><br/><li><a href=""https://jlericson.com/2023/10/16/catija.html"" rel=""nofollow noreferrer"">why Stack Exchange Inc undervalues community managers</a></li><br/><li><a href=""https://jlericson.com/tag/strike"" rel=""nofollow noreferrer"">the moderator strike</a></li><br/><li><a href=""https://jlericson.com/tag/documentation"" rel=""nofollow noreferrer"">documentation</a></li><br/><li><a href=""https://jlericson.com/tag/support"" rel=""nofollow noreferrer"">customer support</a></li><br/></ul><br/><p>I'm Head of Community at <a href=""https://talk.collegeconfidential.com/"" rel=""nofollow noreferrer"">College Confidential</a> and former <a href=""https://jlericson.com/2021/04/30/developer_advocate.html"" rel=""nofollow noreferrer"">Developer Advocate at EDB</a>. Stack Exchange no longer employs me as a <a href=""http://blog.stackoverflow.com/2013/08/please-welcome-jon-ericson-community-manager/"">Community Manager</a>.  I maintain an <a href=""http://chat.meta.stackexchange.com/rooms/738/jons-java-jitter-joint"">office on chat</a>. (Please ignore the meta cruft.)</p><br/><blockquote><br/><p><a href=""https://www.mechon-mamre.org/p/pt/pt2685.htm"" rel=""nofollow noreferrer"">Mercy and truth are met together; righteousness and peace have kissed each other.</a></p><br/></blockquote><br/><p>I write about my experience as a community manager at <a href=""https://jlericson.com/"" rel=""nofollow noreferrer"">jlericson.com</a>. You can read about what I've done over the years in my <a href=""https://web.archive.org/web/20220113195358/https://stackoverflow.com/users/story/1438"" rel=""nofollow noreferrer"" title=""Not guaranteed to be current.""><em>curriculum vitae</em></a>.</p><br/><p>On a personal note, I'm married and have three children.  Our oldest son loves school, friends, games, and music. Two of my children happen to have been born on the same day.  I <a href=""http://taking1and1.wordpress.com/"" rel=""nofollow noreferrer"" title=""Yet another half-assed blog."">sometimes write</a> about that experience. My wife loves taking care of people as a registered nurse and an all around wonderful person.</p><br/><p>Don't have time for a full review of something?  Why not try <a href=""http://fivesecondreview.wordpress.com/"" rel=""nofollow noreferrer"" title=""All reviews accurate and helpful or your money back."">my 5-second reviews</a>?</p><br/><p>I once wrote for <a href=""http://christianity.blogoverflow.com/author/jonericson/"" rel=""nofollow noreferrer"" title=""I haven't been on the rotation for a while, however."">Eschewmenical</a>, which was an experiment of <a href=""http://christianity.stackexchange.com/"">Christianity Stack Exchange</a>. For <em>a lot more</em> writing about the Bible, see <a href=""https://hermeneutics.stackexchange.com/users/68/jon-ericson?tab=summary"">my Biblical Hermeneutics posts</a>.</p><br/><br/>",1083,2015-10-26T22:52:12.923,Jon 'links in bio' Ericson,0,2023-06-04T23:58:02.373,Downtown Burbank,101,0,87,https://jlericson.com/
# 4,"<p>Lover of all things sharp including pencils, wit, and knives but not cheddar.</p><br/>",6254215,2015-10-26T23:18:40.547,Juan M,0,2022-02-11T16:07:18.457,Behind the Glass,101,56,260,
# 5,"<p>I am a Principal Software Engineer at Microsoft working on Azure Functions and related hosting technologies. Formerly the Architecture Lead for Stack Overflow where my day job consisted of being a Developer, Site Reliability Engineer, and DBA.</p><br/><p>I design and build very fast things in hopes of making life easier for millions of developers.</p><br/><p>Blog: <a href=""https://nickcraver.com/blog/"" rel=""nofollow noreferrer"">nickcraver.com/blog</a><br /><br/>Twitter: <a href=""https://twitter.com/Nick_Craver"" rel=""nofollow noreferrer"">@Nick_Craver</a><br /><br/>My Developer Story: <a href=""https://stackoverflow.com/story/ncraver"">stackoverflow.com/story/ncraver</a></p><br/><p><sub>Disclaimer: I have <em>no idea</em> what I'm talking about, all my answers are guesses!</sub></p><br/>",7598,2015-10-26T23:46:20.807,Nick Craver,0,2019-04-02T20:05:34.147,"Winston-Salem, NC",101,0,53,https://nickcraver.com/blog/
# 6,"<p>Chief Technical Officer at <a href=""https://postop.ai"" rel=""nofollow noreferrer"">https://postop.ai</a>.</p><br/><ul><br/><li>Stack Overflow Contributor since 2008</li><br/><li>Skeptics mod since 2011</li><br/><li>Core dev since March 2013</li><br/><li>Stack Overflow alumnus since February 2017</li><br/></ul><br/><p>You can find me on</p><br/><ul><br/><li><a href=""http://sklivvz.com"" rel=""nofollow noreferrer"">Personal site</a></li><br/><li><a href=""https://mastodon.social/@sklivvz"" rel=""nofollow noreferrer"">Mastodon</a></li><br/><li><a href=""https://github.com/sklivvz"" rel=""nofollow noreferrer"">Github</a></li><br/><li><a href=""https://www.linkedin.com/in/sklivvz/"" rel=""nofollow noreferrer"">LinkedIn</a></li><br/></ul><br/>",4623,2015-10-26T23:57:13.187,Sklivvz,0,2017-11-04T17:02:40.430,"Trento, Province of Trento, Italy",101,0,40,https://sklivvz.com
# 7,"<p><a href=""http://blog.stackoverflow.com/2013/09/summer-hiring-happened-so-fast/"">I'm</a> a Web Developer on the Stack Overflow Q&A Core <a href=""http://stackexchange.com/about/team"">team</a>. You can email me via sprelog (at) stackoverflow.com</p><br/>",51875,2015-10-27T07:03:55.417,m0sa,0,2023-01-24T10:24:53.517,Slovenia,101,0,51,
# 8,"<p>My top interests here are:</p><br/><br/><ul><br/><li>Python</li><br/><li>Django</li><br/><li>Software security</li><br/></ul><br/><br/><p>In the past, I used <code>python</code> and <code>django</code> to develop a payment solution at <a href=""https://www.my-bee.fr/pro/"" rel=""nofollow noreferrer"">MyBee</a> - I'm glad they're still going strong today! I also worked at <a href=""http://scalr.com/"" rel=""nofollow noreferrer"">Scalr</a> as a Product Manager, and at <a href=""http://www.accenture.com/"" rel=""nofollow noreferrer"">Accenture</a> as a consultant on business / IT projects. Today, I'm Lead Backend Engineer at <a href=""https://aptible.com"" rel=""nofollow noreferrer"">Aptible</a>.</p><br/><br/><p>Personal email: <code>thomas@orozco.fr</code></p><br/>",467632,2015-10-27T08:25:59.317,Thomas Orozco,0,2017-03-14T23:25:52.540,"Paris, France",101,0,27,

# %% [markdown]
# ## Instalación de la librería `pymongo`

# %%
# %pip install pymongo tqdm[notebook] pandas matplotlib
# Out:
# Collecting pymongo
#   Downloading pymongo-4.11.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: tqdm[notebook] in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: ipywidgets>=6 in /usr/local/lib/python3.11/dist-packages (from tqdm[notebook]) (7.7.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=6->tqdm[notebook]) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=6->tqdm[notebook]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=6->tqdm[notebook]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=6->tqdm[notebook]) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=6->tqdm[notebook]) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=6->tqdm[notebook]) (3.0.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=6->tqdm[notebook]) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=6->tqdm[notebook]) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=6->tqdm[notebook]) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=6->tqdm[notebook]) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=6->tqdm[notebook]) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=6->tqdm[notebook]) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=6->tqdm[notebook]) (6.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=6->tqdm[notebook]) (75.1.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=6->tqdm[notebook])
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=6->tqdm[notebook]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=6->tqdm[notebook]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=6->tqdm[notebook]) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=6->tqdm[notebook]) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=6->tqdm[notebook]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=6->tqdm[notebook]) (4.9.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=6->tqdm[notebook]) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=6->tqdm[notebook]) (5.7.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (3.1.5)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (23.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (1.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=6->tqdm[notebook]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=6->tqdm[notebook]) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=6->tqdm[notebook]) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (4.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (0.23.1)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (4.12.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (1.8.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=6->tqdm[notebook]) (1.3.1)
# Downloading pymongo-4.11.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 36.8 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 19.8 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 49.7 MB/s eta 0:00:00
# Installing collected packages: jedi, dnspython, pymongo
# Successfully installed dnspython-2.7.0 jedi-0.19.2 pymongo-4.11.2

# %%
from pprint import pprint as pp
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline
matplotlib.style.use('ggplot')

# %% [markdown]
# Usaremos la librería `pymongo` para python. La cargamos a continuación.

# %%
from pymongo import MongoClient

# %% [markdown]
# ## Conexión a la base de datos

# %% [markdown]
# La conexión se inicia con `MongoClient` en el `host` descrito en el fichero `docker-compose.yml` (`mongo`), o bien a `localhost` si lo estamos haciendo en Colab.

# %%
import os
db_hostname: str = "localhost" if RunningInCOLAB else os.getenv('DB_HOSTNAME', "mongo")

# %%
from typing import Any

client: MongoClient[dict[str, Any]] = MongoClient(db_hostname,27017)
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'local']

# %% [markdown]
# Las bases de datos se crean conforme se nombran. Se puede utilizar la notación punto o la de diccionario. Las colecciones también.

# %%
from pymongo.database import Database

db: Database = client.stackoverflow
# db: Database = client['stackoverflow'] # (equivalente)
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stackoverflow')

# %% [markdown]
# ## Importación de los ficheros CSV
#
# Por ahora creamos una colección diferente para cada uno. Después estudiaremos cómo poder optimizar el acceso usando agregación.

# %%
import csv
import sys
from datetime import datetime
from pymongo.collection import Collection
from typing import Any
from collections.abc import Callable, Iterable, Iterator
from tqdm.notebook import tqdm

def batched(iterable: Iterable, n) -> Iterable:
    from itertools import islice
    if n < 1:
        raise ValueError('n must be at least one')
    it: Iterator = iter(iterable)
    while batch := tuple(islice(it, n)):
        yield batch

def csv_to_mongo(file: str, coll: Collection):
    """
    Carga un fichero CSV en Mongo. file especifica el fichero, coll la colección
    dentro de la base de datos, y date_cols las columnas que serán interpretadas
    como fechas.
    """
    # Convertir todos los elementos que se puedan a números
    def to_numeric(d: str) -> str| int | float:
        if len(d) == 0:
            return ''
        if not ((d[0] >= '0' and d[0] <= '9') or d[0] == '-' or d[0] == '+' or d[0]=='.'):
            return d
        try:
            return int(d) if abs(int(d)) <= sys.maxsize else d # Ensure number is inside MongoDB max number range
        except ValueError:
            try:
                return float(d)
            except ValueError:
                return d

    def to_date(d: str) -> datetime | None:
        """To ISO Date. If this cannot be converted, return NULL (None)"""
        try:
            return datetime.strptime(d, "%Y-%m-%dT%H:%M:%S.%f")
        except ValueError:
            return None

    coll.drop()

    with open(file, encoding='utf-8') as f:
        # La llamada csv.reader() crea un iterador sobre un fichero CSV
        reader = csv.reader(f, dialect='excel')

        # Se leen las columnas. Sus nombres se usarán para crear las diferentes columnas en la familia
        columns: list[str] = next(reader)

        # Las columnas que contienen 'Date' se interpretan como fechas
        func_to_cols: list[Callable[[str], Any]] = list(map(lambda c: to_date if 'date' in c.lower() else to_numeric, columns))

        for batch in batched(tqdm(reader, desc='Leyendo e insertando filas...'), 10000):
            docs: list[dict[str, str | datetime | float | int | None]] = []
            for row in batch:
                built_row: list[str | datetime | float | int | None] = [func(e) for (func,e) in zip(func_to_cols, row)]
                docs.append(dict(zip(columns, built_row)))
            coll.insert_many(docs)

        print("¡Hecho!")

# %%
csv_to_mongo('Posts.csv',db.posts)
# Out:
# Leyendo e insertando filas...: 0it [00:00, ?it/s]
# ¡Hecho!

# %%
csv_to_mongo('Users.csv',db.users)
# Out:
# Leyendo e insertando filas...: 0it [00:00, ?it/s]
# ¡Hecho!

# %%
csv_to_mongo('Votes.csv',db.votes)
# Out:
# Leyendo e insertando filas...: 0it [00:00, ?it/s]
# ¡Hecho!

# %%
csv_to_mongo('Comments.csv',db.comments)
# Out:
# Leyendo e insertando filas...: 0it [00:00, ?it/s]
# ¡Hecho!

# %%
csv_to_mongo('Tags.csv',db.tags)
# Out:
# Leyendo e insertando filas...: 0it [00:00, ?it/s]
# ¡Hecho!

# %%
posts: Collection[dict[str, Any]] = db.posts
posts
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stackoverflow'), 'posts')

# %%
posts.count_documents({})
# Out:
# 410346

# %% [markdown]
# ## Framework de Agregación
#
# Framework de agregación:
# - Aquí está la referencia de las diferentes etapas por las que puede pasar un pipeline: https://www.mongodb.com/docs/manual/reference/operator/aggregation-pipeline/.
# - Y aquí los distintos operadores que se permiten dentro de las etapas: https://docs.mongodb.com/manual/reference/operator/aggregation/.
# - Y aquí incluso un libro completo con usos prácticos de ejecutar agregación: https://www.practical-mongodb-aggregations.com/.
#
# A continuación un vídeo interesante:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('VSX4a3h4SmQ',width=600)

# %% [markdown]
# Aqui tenemos un esquema con un ejemplo básico de agregación.

# %% [markdown]
# ![](https://miro.medium.com/max/1060/1*2lDBxvZ8Cr3JYkoODTa0lQ.png)

# %% [markdown]
# ## Algunos operadores de agregación

# %% [markdown]
# ### `$match`
#
# Este operador permite filtrar los documentos que queremos que pasen a la siguiente fase del pipeline definiendo una serie de condiciones sobre los campos de los mismos.
#
# Vamos a filtrar aquellos documentos que tengan un `Score` igual o superior (`$gte`) a 150.

# %%
from pymongo.command_cursor import CommandCursor

respuestas: CommandCursor[dict[str, Any]] = posts.aggregate( [
        {'$match': { 'Score' : {'$gte': 150}}}
])
list(respuestas)
# Out:
# [{'_id': ObjectId('67c9e68502ff02b3f27e1e46'),
#   'Id': 40,
#   'AcceptedAnswerId': '',
#   'AnswerCount': '',
#   'Body': '<p>Asumiendo que se está haciendo un <code>join</code> de columnas sin duplicados, lo cuál es un caso común:</p><br/><ul><br/><li><p>Un <strong>inner join</strong> de A y B entregará el resultado de la intersección de los conjuntos A y B. En otras palabras, la parte <em>interna</em> –intersección– en un diagrama de Venn.</p><br/></li><br/><li><p>Un <strong>full outer join</strong> entre A y B entregará el resultado de la unión de A y B. En otras palabras, la parte <em>externa</em> –unión– en un diagrama de Venn .</p><br/></li><br/></ul><br/><h1>Ejemplos:</h1><br/><p>Supongamos que tenemos dos tablas, con una sola columna cada una y los siguientes datos:</p><br/><pre><code>A    B<br/>-    -<br/>1    3<br/>2    4<br/>3    5<br/>4    6<br/></code></pre><br/><p>Nota que (1,2) solo se encuentran en A, (3,4) son comunes y (5,6) solamente se encuentran en B.</p><br/><h1>Inner Join</h1><br/><p>Un inner join –utilizando cualquiera de las sintaxis de consulta equivalente– te entrega la intersección de ambas tablas, es decir, las filas que ambas tablas tienen en común.</p><br/><pre><code>select * from a INNER JOIN b on a.a = b.b;<br/>select a.*, b.*  from a, b where a.a = b.b;<br/><br/>a | b<br/>--+--<br/>3 | 3<br/>4 | 4<br/></code></pre><br/><h1>Left outer join</h1><br/><p>Un <code>outer join</code> por la izquierda, te dará todas las filas de A, incluyendo las filas comunes entre A y B.</p><br/><pre><code>select * from a LEFT OUTER JOIN b on a.a = b.b;<br/>select a.*,b.*  from a,b where a.a = b.b(+);<br/><br/>a |  b<br/>--+-----<br/>1 | null<br/>2 | null<br/>3 |    3<br/>4 |    4<br/></code></pre><br/><h1>Right outer join</h1><br/><p>Un <code>outer join</code> por la derecha te dará todas las filas de B, incluyendo las filas comunes con A.</p><br/><pre><code>select * from a RIGHT OUTER JOIN b on a.a = b.b;<br/>select a.*,b.*  from a,b where a.a(+) = b.b;<br/><br/>a    |  b<br/>-----+----<br/>3    |  3<br/>4    |  4<br/>null |  5<br/>null |  6<br/></code></pre><br/><h1>Full outer join</h1><br/><p>Un <code>outer join</code> completo (full) te entregará la unión de A y B; es decir, todas las filas de A y todas las filas de B. Si una fila en A no tiene una fila correspondiente en B, la porción de B es null, y vice versa.</p><br/><pre><code>select * from a FULL OUTER JOIN b on a.a = b.b;<br/><br/> a   |  b<br/>-----+-----<br/>   1 | null<br/>   2 | null<br/>   3 |    3<br/>   4 |    4<br/>null |    5<br/>null |    6<br/></code></pre><br/><h1>Diagramas de Venn</h1><br/><p>Esto mismo, podemos verlo con diagramas de Venn:</p><br/><p><img src="https://upload.wikimedia.org/wikipedia/commons/e/eb/SQL_Joins_es.svg" alt="Explicación visual de joins" /><br/>Imagen <a href="https://commons.wikimedia.org/wiki/File:SQL_Joins_es.svg" rel="nofollow noreferrer">SQL_Joins_es.svg</a> de <a href="https://es.stackoverflow.com/users/21/jachguate">jachguate</a>/<a href="https://commons.wikimedia.org/wiki/User:Arbeck" rel="nofollow noreferrer">Arbeck</a>, compartida bajo licencia <a href="https://creativecommons.org/licenses/by/3.0/deed.en" rel="nofollow noreferrer">CC BY 3.0</a>.</p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 4,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 4.0',
#   'CreationDate': datetime.datetime(2015, 11, 2, 17, 8, 19, 893000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2023, 7, 12, 6, 22, 59, 157000),
#   'LastEditDate': datetime.datetime(2023, 7, 12, 6, 22, 59, 157000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 21,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 21,
#   'ParentId': 36,
#   'PostTypeId': 2,
#   'Score': 206,
#   'Tags': '',
#   'Title': '',
#   'ViewCount': ''},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1ec6'),
#   'Id': 197,
#   'AcceptedAnswerId': '',
#   'AnswerCount': 13,
#   'Body': '<p>Unas veces los cálculos funcionan correctamente, pero otras veces no:</p><br/><br/><pre><code>> 0.1 + 0.1<br/>0.2 // correcto<br/>> 0.1 + 0.2<br/>0.30000000000000004 // ¿qué?<br/>> 10 * 0.67<br/>6.7 // correcto<br/>> 10 * 0.68<br/>6.800000000000001 // demasiado grande<br/>> 10 * 0.69<br/>6.8999999999999995 // demasiado pequeño<br/></code></pre><br/><br/><p>(Estos ejemplos están escritos en JavaScript, pero el mismo problema existe en muchos lenguajes de programación)</p><br/><br/><p>Estos cálculos son bastante fáciles: creo que todos podemos hacerlos en un momento. ¿Por qué mis programas no pueden hacer cálculos aritméticos correctamente, y qué puedo hacer si necesito resultados más precisos?</p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 10,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2015, 12, 2, 6, 15, 7, 957000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2023, 2, 6, 22, 11, 20, 880000),
#   'LastEditDate': datetime.datetime(2015, 12, 5, 20, 22, 47, 177000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 20,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 416,
#   'ParentId': '',
#   'PostTypeId': 1,
#   'Score': 176,
#   'Tags': '<matemáticas><coma-flotante><lenguaje-agnóstico>',
#   'Title': '¿Por qué mis programas no pueden hacer cálculos aritméticos correctamente?',
#   'ViewCount': 9091},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1eca'),
#   'Id': 204,
#   'AcceptedAnswerId': '',
#   'AnswerCount': '',
#   'Body': '<p>El problema viene de la limitación que los ordenadores tienen para representar números de <a href="https://es.wikipedia.org/wiki/Coma_flotante">coma flotante</a> usando un número finito de bits.</p><br/><br/><p><a href="http://www.exploringbinary.com/why-0-point-1-does-not-exist-in-floating-point">En este artículo en inglés</a> hay una muy buena explicación. Básicamente, para representar el número 0.1 en coma flotante necesitamos un número infinito de dígitos binarios:</p><br/><br/><p><a href="https://i.stack.imgur.com/e5fNJ.png"><img src="https://i.stack.imgur.com/e5fNJ.png" alt="Dividiendo 1 entre 10 en binario"></a></p><br/><br/><p><em>Dividiendo 1 entre 10 en binario</em></p><br/><br/><p><a href="https://i.stack.imgur.com/rvPPD.png"><img src="https://i.stack.imgur.com/rvPPD.png" alt="1/10 en binario (primeros 1369 dígitos)"></a></p><br/><br/><p><em>1/10 en binario (primeros 1369 dígitos)</em></p><br/><br/><p>Si suponemos que nuestro ordenador es capaz de almacenar hasta 53 dígitos, una vez truncado nuestro 0.1 queda representado en binario como:</p><br/><br/><p>0.0001100110011001100110011001100110011001100110011001101</p><br/><br/><p>...que en decimal es</p><br/><br/><p>0.1000000000000000055511151231257827021181583404541015625</p><br/><br/><p>Para este problema hay básicamente dos soluciones:</p><br/><br/><ul><br/><li>Usar un tipo decimal exacto en vez de coma flotante. Hay lenguajes que proporcionan estos tipos nativamente (por ejemplo, .NET tiene el tipo <a href="https://msdn.microsoft.com/en-us/library/364x0z75.aspx">decimal</a>); para los que no, suele haber librerías especializadas para ello (por ejemplo <a href="https://github.com/MikeMcl/decimal.js">decimal.js</a> para Javascript).</li><br/><li>Si el número de decimales se conoce por adelantado (por ejemplo al tratar con valores monetarios), los valores se pueden representar como enteros. Así, 123.45€ se representaría como 12345 céntimos. El punto decimal se añadiría al final, a la hora de mostrar el valor al usuario.</li><br/></ul><br/><br/><p>Un buen sitio con más información sobre este tema: <a href="http://puntoflotante.org">http://puntoflotante.org</a></p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 3,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2015, 12, 2, 7, 43, 50, 70000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2015, 12, 2, 9, 56, 34, 630000),
#   'LastEditDate': datetime.datetime(2015, 12, 2, 9, 56, 34, 630000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 23,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 23,
#   'ParentId': 197,
#   'PostTypeId': 2,
#   'Score': 195,
#   'Tags': '',
#   'Title': '',
#   'ViewCount': ''},
#  {'_id': ObjectId('67c9e68702ff02b3f27e5694'),
#   'Id': 18232,
#   'AcceptedAnswerId': 18233,
#   'AnswerCount': 6,
#   'Body': '<p>Las sentencias dinámicas son sentencias SQL que se crean como cadenas de texto (strings) y en las que se insertan/concatenan valores obtenidos de alguna fuente (normalmente proveniente del usuario), lo que puede hacer que sean vulnerables a inyección SQL si no se sanean las entradas, como por ejemplo:</p><br/><br/><pre><code>$id_usuario = $_POST["id"];<br/><br/>mysql_query("SELECT * FROM usuarios WHERE id = $id_usuario");<br/></code></pre><br/><br/><p>Eso es un ejemplo de una vulnerabilidad grave en la seguridad de una aplicación (web o no) porque si el usuario introdujese un valor como <code>1; DROP TABLE usuarios;--</code> nos encontraríamos con que la sentencia ejecutada sería:</p><br/><br/><pre><code>SELECT * FROM usuarios WHERE id = 1; DROP TABLE usuarios;--<br/></code></pre><br/><br/><p>Y se eliminaría la tabla Usuarios con todos los datos contenidos en ella. </p><br/><br/><p><strong>¿Cómo puedo evitar que la inyección SQL ocurra en PHP?</strong></p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 1,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2016, 7, 31, 21, 3, 26, 190000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2023, 5, 16, 22, 14, 53, 633000),
#   'LastEditDate': datetime.datetime(2017, 3, 4, 3, 8, 9, 33000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 29967,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 250,
#   'ParentId': '',
#   'PostTypeId': 1,
#   'Score': 232,
#   'Tags': '<php><mysql><sql><seguridad><inyección-sql>',
#   'Title': '¿Cómo evitar la inyección SQL en PHP?',
#   'ViewCount': 77113},
#  {'_id': ObjectId('67c9e68702ff02b3f27e5695'),
#   'Id': 18233,
#   'AcceptedAnswerId': '',
#   'AnswerCount': '',
#   'Body': '<blockquote><br/><h1>NO USES SENTENCIAS DINÁMICAS NI FUNCIONES <code>mysql_*</code></h1><br/><p>Las funciones <code>mysql_*</code> (<code>mysql_connect</code>, <code>mysql_query</code>, etc.) son inseguras por naturaleza y su uso no sólo no está recomendado, sino que <strong>se consideran obsoletas y se han eliminado completamente a partir de PHP7</strong>.</p><br/><p>Incluso los métodos nativos que existen en PHP para sanear las entradas de usuario (como <code>mysql_real_escape_string</code>) pueden presentar (raros) problemas y fallar en algunos casos como cuando se usan codificación de caracteres diferentes a UTF-8 junto a versiones no actualizadas de MySQL (en las <a href="http://php.net/manual/es/mysqli.real-escape-string.php" rel="noreferrer">páginas de PHP para estas funciones</a> se avisa de este riesgo).</p><br/></blockquote><br/><hr /><br/><h1>Usa sentencias preparadas y consultas parametrizadas</h1><br/><p>Aunque se podrían sanear las entradas usando métodos como <code>mysqli_real_escape_string</code>, es más recomendable la utilización de sentencias preparadas o parametrizadas. Las sentencias preparadas te permitirán ejecutar la misma sentencia con gran eficiencia.</p><br/><p>En PHP, tienes dos alternativas principales: <a href="https://www.php.net/manual/es/book.pdo.php" rel="noreferrer">PDO</a> y  <a href="https://www.php.net/manual/es/book.mysqli.php" rel="noreferrer">MySQLi</a>. Hay varias diferencias entre ambas, pero la principal es que PDO se puede usar con diferentes tipos de base de datos (<a href="https://www.php.net/manual/es/intro.pdo.php#intro.pdo" rel="noreferrer">dependiendo del driver utilizado</a>) mientras que MySQLi es exclusivamente para bases de datos MySQL. Es por ello que recomendaría PDO sobre MySQLi.</p><br/><h2>PDO</h2><br/><p>Los <a href="https://www.php.net/manual/es/pdo.prepare.php#refsect1-pdo.prepare-description" rel="noreferrer">marcadores de posición</a> (que indican dónde se sustituirá una cadena por su valor), se pueden definir bien usando un signo de interrogación (<code>?</code>) o bien usando un nombre (generalmente empezando con <code>:</code>). Personalmente prefiero usar un nombre, porque eso me ayuda a encontrar posibles errores en caso de tener múltiples variables.</p><br/><p>Aquí dejo un ejemplo para el código de la pregunta:</p><br/><pre><code>// la variable $pdo contendrá el objeto con la conexión PDO<br/>$pdo = new PDO(\'mysql:host=mihost;dbname=basedatos\', "usuario", "contraseña");<br/><br/>$id_usuario = $_POST["id"];<br/><br/>$sentencia = $pdo->prepare("SELECT * FROM usuarios WHERE id = :idusuario");<br/>$sentencia=$pdo->setAttribute(PDO::ATTR_EMULATE_PREPARES, false);<br/>$sentencia->bindParam(":idusuario", $id_usuario, PDO::PARAM_INT);<br/>$sentencia->execute();<br/></code></pre><br/><p>En este caso, <code>:idusuario</code> se sustituirá por el valor de <code>$_POST["id"]</code> de forma segura, y cuando hace el <em>bind</em> se indica que la variable es de tipo entero (<code>PDO::PARAM_INT</code>).</p><br/><blockquote><br/><p>Nota: si la variable es una cadena de texto se usará <code>PDO::PARAM_STR</code> y no hace falta poner las comillas en la sentencia SQL; al especificarle a PHP que es una cadena, las añadirá automáticamente al hacer el <em>bind</em>.</p><br/></blockquote><br/><p>En caso de que existan varias variables a incluir en la sentencia SQL, se debe incluir un único parámetro para cada uno de los valores que se usan en la sentencia. Del ejemplo anterior, el <code>:idusuario</code> puede usarse una única vez en la consulta que se esta preparando. Si fuera necesario usar el "idusuario" de nuevo en la consulta, se debe crear otro parámetro con el valor de <code>$id_usuario</code>.</p><br/><pre><code>$pdo = new PDO(\'mysql:host=mihost;dbname=basedatos\', "usuario", "contraseña");<br/><br/>$id_usuario = $_POST["id"];<br/>    <br/>$sentencia = $pdo->prepare("UPDATE usuarios SET id = :idusuario WHERE id = :idusuario1");<br/>$sentencia=$pdo->setAtt ...
#   'ClosedDate': None,
#   'CommentCount': 4,
#   'CommunityOwnedDate': datetime.datetime(2016, 7, 31, 21, 3, 26, 190000),
#   'ContentLicense': 'CC BY-SA 4.0',
#   'CreationDate': datetime.datetime(2016, 7, 31, 21, 3, 26, 190000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2022, 8, 13, 1, 55, 39, 97000),
#   'LastEditDate': datetime.datetime(2022, 8, 13, 1, 55, 39, 97000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 195444,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 250,
#   'ParentId': 18232,
#   'PostTypeId': 2,
#   'Score': 219,
#   'Tags': '',
#   'Title': '',
#   'ViewCount': ''},
#  {'_id': ObjectId('67c9e69202ff02b3f27f1f4b'),
#   'Id': 87842,
#   'AcceptedAnswerId': '',
#   'AnswerCount': '',
#   'Body': '<p>Hola, mi nombre es Álvaro Montoro, soy un Ingeniero Informático español aunque actualmente vivo y trabajo en los Estados Unidos, en la capital del estado de Texas: Austin.</p><br/><br/><p>Tengo experiencia en diferentes ámbitos de programación: back-end, front-end, bases de datos, seguridad... y en bastantes lenguajes: PHP, Java, C#, Visual Basic, C/C++, JavaScript... lo que hace que me mueva por un grupo variado de etiquetas (aunque prefiera las de programación web) y se refleja en la medalla <a href="https://es.stackoverflow.com/help/badges/15/generalist"><code>generalista</code></a> (de momento el único que la tiene).</p><br/><br/><p>Pros:</p><br/><br/><ul><br/><li>Paso bastante tiempo en SOes (he visitado el sitio 594 días, 384 consecutivos ).</li><br/><li>He estado en el sitio desde Area 51 y cuento con experiencia en otros sitios de SE (no como moderador).</li><br/><li>Me gusta guiarme por las reglas del Centro de Ayuda.</li><br/></ul><br/><br/><p>Contras:</p><br/><br/><ul><br/><li>Aunque activo en chat y meta, debería ser más activo.</li><br/><li>Cuento con experiencia en otros sitios de SE, lo que hace que a veces use la misma vara de medir que usaría en otros sitios.</li><br/><li>Me gusta guiarme por las reglas del Centro de Ayuda... y a veces hay que ser más paciente y flexible.</li><br/></ul><br/>',
#   'ClosedDate': None,
#   'CommentCount': 12,
#   'CommunityOwnedDate': datetime.datetime(2017, 7, 18, 20, 7, 26, 473000),
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2017, 7, 18, 20, 7, 26, 473000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2017, 7, 20, 15, 58, 45, 867000),
#   'LastEditDate': datetime.datetime(2017, 7, 20, 15, 58, 45, 867000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 250,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 250,
#   'ParentId': '',
#   'PostTypeId': 6,
#   'Score': 173,
#   'Tags': '',
#   'Title': '',
#   'ViewCount': ''}]

# %% [markdown]
# ### `$project`
#
# El operador `$project`permite filtar qué campos de los documentos queremos usar en la siguientes fases de agregación.
#
# Generalmente este operador suele combinarse con otros como `$find`, `$match` o `$lookup` en fases más avanzadas de la agregación.
#
# En el siguiente ejemplo, realizamos un filtrado en donde solo nos quedamos con el campo `Id` de los posts.

# %%
respuestas: CommandCursor[dict[str, Any]] = db['posts'].aggregate( [
    {'$project' : { 'Id' : True }},
    {'$limit': 20} ])
list(respuestas)
# Out:
# [{'_id': ObjectId('67c9e68502ff02b3f27e1e22'), 'Id': 1},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e23'), 'Id': 2},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e24'), 'Id': 3},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e25'), 'Id': 4},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e26'), 'Id': 5},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e27'), 'Id': 6},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e28'), 'Id': 7},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e29'), 'Id': 8},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e2a'), 'Id': 9},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e2b'), 'Id': 10},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e2c'), 'Id': 11},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e2d'), 'Id': 12},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e2e'), 'Id': 14},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e2f'), 'Id': 15},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e30'), 'Id': 16},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e31'), 'Id': 17},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e32'), 'Id': 18},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e33'), 'Id': 19},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e34'), 'Id': 20},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1e35'), 'Id': 21}]

# %% [markdown]
# ### `$group`
#
# La función `$group` se usa dentro del *pipeline* de agregación de documentos seguido por Mongo (`.aggregate`). Esta función admite dos parámetros diferentes:
# * `_id`: El identificador por el que queremos agrupar los documentos.
# * `campo`: Expresión mediante la cual queremos aggregar los documentos (*opcional*).

# %% [markdown]
# Vamos a contar el número de posts por `OwnerUserId` en la colección `posts`.

# %%
from pymongo.command_cursor import CommandCursor

users_count_scores: CommandCursor[dict[str, Any]] = db.posts.aggregate(
    [
        {
            "$group":{
                "_id": "$OwnerUserId",
                "count": {"$sum": 1}
            }
        },
        {
            "$limit": 10
        }
    ]
)
list(users_count_scores)
# Out:
# [{'_id': 61917, 'count': 2},
#  {'_id': 305255, 'count': 1},
#  {'_id': 98967, 'count': 4},
#  {'_id': 315423, 'count': 1},
#  {'_id': 177363, 'count': 1},
#  {'_id': 2838, 'count': 8},
#  {'_id': 148177, 'count': 1},
#  {'_id': 319220, 'count': 1},
#  {'_id': 160914, 'count': 3},
#  {'_id': 160225, 'count': 1}]

# %% [markdown]
# Ahora vamos computar el `score` medio por usuario en base a todos sus posts.

# %%
users_avg_scores: CommandCursor[dict[str, Any]] = db.posts.aggregate(
    [{
        "$group":{
            "_id": "$OwnerUserId",
            "avg_score": {"$avg":'$Score'}
        }
        },
        { "$limit": 10 }
    ]
)
list (users_avg_scores)
# Out:
# [{'_id': 61917, 'avg_score': 0.5},
#  {'_id': 305255, 'avg_score': 1.0},
#  {'_id': 98967, 'avg_score': 1.0},
#  {'_id': 315423, 'avg_score': 0.0},
#  {'_id': 177363, 'avg_score': 1.0},
#  {'_id': 2838, 'avg_score': 1.75},
#  {'_id': 148177, 'avg_score': 1.0},
#  {'_id': 319220, 'avg_score': 0.0},
#  {'_id': 160914, 'avg_score': 1.0},
#  {'_id': 160225, 'avg_score': 0.0}]

# %% [markdown]
# ### `$lookup`

# %% [markdown]
# El operador `$lookup` permite realizar búsquedas en otras colecciones. Podrían interpretarse como un *join* en el modelo relacional. Esta función admite cuatro parámetros diferentes:
#
# *   `from`: especifica la colección en la misma base de datos con la que hacer la búsqueda (o el *join*).
# *   `localField`: Especifica el campo de los documentos de entrada a usar para realizar una comparación de igualdad con el campo `foreignField` de los documentos de la colección `from`.
# *   `foreignField`: Especifica el campo de los documentos de la colección `from` a usar en la comparación de igualdad con el `localField`.
# *   `as`: Especifica el nombre del nuevo campo array que se añadirá a los documentos de entrada. Este nuevo campo contiene los documentos coincidentes de la colección `from`.
#
# En el ejemplo siguiente, en primer lugar seleccionamos los posts con un `Score` igual o mayor a 150 con `$match` para a continuación seleccionar los usuarios que han publicado dichos posts incluyéndolo en un nuevo campo llamado `owner`.

# %%
respuestas: CommandCursor[dict[str, Any]] = posts.aggregate( [
    {'$match': { 'Score' : {'$gte': 150}}},
    {'$lookup': {
        'from': "users",
        'localField': "OwnerUserId",
        'foreignField': "Id",
        'as': "owner"}
    }
])
list(respuestas)
# Out:
# [{'_id': ObjectId('67c9e68502ff02b3f27e1e46'),
#   'Id': 40,
#   'AcceptedAnswerId': '',
#   'AnswerCount': '',
#   'Body': '<p>Asumiendo que se está haciendo un <code>join</code> de columnas sin duplicados, lo cuál es un caso común:</p><br/><ul><br/><li><p>Un <strong>inner join</strong> de A y B entregará el resultado de la intersección de los conjuntos A y B. En otras palabras, la parte <em>interna</em> –intersección– en un diagrama de Venn.</p><br/></li><br/><li><p>Un <strong>full outer join</strong> entre A y B entregará el resultado de la unión de A y B. En otras palabras, la parte <em>externa</em> –unión– en un diagrama de Venn .</p><br/></li><br/></ul><br/><h1>Ejemplos:</h1><br/><p>Supongamos que tenemos dos tablas, con una sola columna cada una y los siguientes datos:</p><br/><pre><code>A    B<br/>-    -<br/>1    3<br/>2    4<br/>3    5<br/>4    6<br/></code></pre><br/><p>Nota que (1,2) solo se encuentran en A, (3,4) son comunes y (5,6) solamente se encuentran en B.</p><br/><h1>Inner Join</h1><br/><p>Un inner join –utilizando cualquiera de las sintaxis de consulta equivalente– te entrega la intersección de ambas tablas, es decir, las filas que ambas tablas tienen en común.</p><br/><pre><code>select * from a INNER JOIN b on a.a = b.b;<br/>select a.*, b.*  from a, b where a.a = b.b;<br/><br/>a | b<br/>--+--<br/>3 | 3<br/>4 | 4<br/></code></pre><br/><h1>Left outer join</h1><br/><p>Un <code>outer join</code> por la izquierda, te dará todas las filas de A, incluyendo las filas comunes entre A y B.</p><br/><pre><code>select * from a LEFT OUTER JOIN b on a.a = b.b;<br/>select a.*,b.*  from a,b where a.a = b.b(+);<br/><br/>a |  b<br/>--+-----<br/>1 | null<br/>2 | null<br/>3 |    3<br/>4 |    4<br/></code></pre><br/><h1>Right outer join</h1><br/><p>Un <code>outer join</code> por la derecha te dará todas las filas de B, incluyendo las filas comunes con A.</p><br/><pre><code>select * from a RIGHT OUTER JOIN b on a.a = b.b;<br/>select a.*,b.*  from a,b where a.a(+) = b.b;<br/><br/>a    |  b<br/>-----+----<br/>3    |  3<br/>4    |  4<br/>null |  5<br/>null |  6<br/></code></pre><br/><h1>Full outer join</h1><br/><p>Un <code>outer join</code> completo (full) te entregará la unión de A y B; es decir, todas las filas de A y todas las filas de B. Si una fila en A no tiene una fila correspondiente en B, la porción de B es null, y vice versa.</p><br/><pre><code>select * from a FULL OUTER JOIN b on a.a = b.b;<br/><br/> a   |  b<br/>-----+-----<br/>   1 | null<br/>   2 | null<br/>   3 |    3<br/>   4 |    4<br/>null |    5<br/>null |    6<br/></code></pre><br/><h1>Diagramas de Venn</h1><br/><p>Esto mismo, podemos verlo con diagramas de Venn:</p><br/><p><img src="https://upload.wikimedia.org/wikipedia/commons/e/eb/SQL_Joins_es.svg" alt="Explicación visual de joins" /><br/>Imagen <a href="https://commons.wikimedia.org/wiki/File:SQL_Joins_es.svg" rel="nofollow noreferrer">SQL_Joins_es.svg</a> de <a href="https://es.stackoverflow.com/users/21/jachguate">jachguate</a>/<a href="https://commons.wikimedia.org/wiki/User:Arbeck" rel="nofollow noreferrer">Arbeck</a>, compartida bajo licencia <a href="https://creativecommons.org/licenses/by/3.0/deed.en" rel="nofollow noreferrer">CC BY 3.0</a>.</p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 4,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 4.0',
#   'CreationDate': datetime.datetime(2015, 11, 2, 17, 8, 19, 893000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2023, 7, 12, 6, 22, 59, 157000),
#   'LastEditDate': datetime.datetime(2023, 7, 12, 6, 22, 59, 157000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 21,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 21,
#   'ParentId': 36,
#   'PostTypeId': 2,
#   'Score': 206,
#   'Tags': '',
#   'Title': '',
#   'ViewCount': '',
#   'owner': [{'_id': ObjectId('67c9e6c002ff02b3f2846121'),
#     'Id': 21,
#     'AboutMe': '<p>Entrepreneur, software developer and <strong>traveler</strong>. :)</p><br/>',
#     'AccountId': 93263,
#     'CreationDate': datetime.datetime(2015, 10, 29, 13, 46, 46, 317000),
#     'DisplayName': 'jachguate',
#     'DownVotes': 281,
#     'LastAccessDate': datetime.datetime(2023, 11, 28, 16, 55, 27, 633000),
#     'Location': 'Guatemala',
#     'Reputation': 30128,
#     'UpVotes': 2727,
#     'Views': 2892,
#     'WebsiteUrl': 'http://jachguate.wordpress.com'}]},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1ec6'),
#   'Id': 197,
#   'AcceptedAnswerId': '',
#   'AnswerCount': 13,
#   'Body': '<p>Unas veces los cálculos funcionan correctamente, pero otras veces no:</p><br/><br/><pre><code>> 0.1 + 0.1<br/>0.2 // correcto<br/>> 0.1 + 0.2<br/>0.30000000000000004 // ¿qué?<br/>> 10 * 0.67<br/>6.7 // correcto<br/>> 10 * 0.68<br/>6.800000000000001 // demasiado grande<br/>> 10 * 0.69<br/>6.8999999999999995 // demasiado pequeño<br/></code></pre><br/><br/><p>(Estos ejemplos están escritos en JavaScript, pero el mismo problema existe en muchos lenguajes de programación)</p><br/><br/><p>Estos cálculos son bastante fáciles: creo que todos podemos hacerlos en un momento. ¿Por qué mis programas no pueden hacer cálculos aritméticos correctamente, y qué puedo hacer si necesito resultados más precisos?</p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 10,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2015, 12, 2, 6, 15, 7, 957000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2023, 2, 6, 22, 11, 20, 880000),
#   'LastEditDate': datetime.datetime(2015, 12, 5, 20, 22, 47, 177000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 20,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 416,
#   'ParentId': '',
#   'PostTypeId': 1,
#   'Score': 176,
#   'Tags': '<matemáticas><coma-flotante><lenguaje-agnóstico>',
#   'Title': '¿Por qué mis programas no pueden hacer cálculos aritméticos correctamente?',
#   'ViewCount': 9091,
#   'owner': [{'_id': ObjectId('67c9e6c002ff02b3f284628b'),
#     'Id': 416,
#     'AboutMe': '<p><strong>Projects</strong></p><br/><br/><ul><br/><li><a href="https://www.dong-chinese.com/" rel="nofollow noreferrer">Dong Chinese</a></li><br/><li><a href="https://github.com/peterolson/BigInteger.js" rel="nofollow noreferrer">BigInteger.js</a></li><br/><li><a href="http://www.virtualtrebuchet.com/" rel="nofollow noreferrer">Virtual Trebuchet</a></li><br/><li><a href="https://play.google.com/store/apps/details?id=com.peterolson.magnetpuzzle" rel="nofollow noreferrer">The Magnet Puzzle</a></li><br/></ul><br/><br/><h2><img src="https://projecteuler.net/profile/peter.olson.png" alt="enter image description here"></h2><br/><br/><p>You can contact me at </p><br/><br/><pre><code>peter.e.c.olson+stackexchange@gmail.com<br/></code></pre><br/>',
#     'AccountId': 262054,
#     'CreationDate': datetime.datetime(2015, 12, 2, 0, 35, 33, 333000),
#     'DisplayName': 'Peter Olson',
#     'DownVotes': 0,
#     'LastAccessDate': datetime.datetime(2022, 12, 5, 14, 52, 5, 970000),
#     'Location': 'Qingdao, China',
#     'Reputation': 4795,
#     'UpVotes': 7,
#     'Views': 178,
#     'WebsiteUrl': 'https://www.dong-chinese.com'}]},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1eca'),
#   'Id': 204,
#   'AcceptedAnswerId': '',
#   'AnswerCount': '',
#   'Body': '<p>El problema viene de la limitación que los ordenadores tienen para representar números de <a href="https://es.wikipedia.org/wiki/Coma_flotante">coma flotante</a> usando un número finito de bits.</p><br/><br/><p><a href="http://www.exploringbinary.com/why-0-point-1-does-not-exist-in-floating-point">En este artículo en inglés</a> hay una muy buena explicación. Básicamente, para representar el número 0.1 en coma flotante necesitamos un número infinito de dígitos binarios:</p><br/><br/><p><a href="https://i.stack.imgur.com/e5fNJ.png"><img src="https://i.stack.imgur.com/e5fNJ.png" alt="Dividiendo 1 entre 10 en binario"></a></p><br/><br/><p><em>Dividiendo 1 entre 10 en binario</em></p><br/><br/><p><a href="https://i.stack.imgur.com/rvPPD.png"><img src="https://i.stack.imgur.com/rvPPD.png" alt="1/10 en binario (primeros 1369 dígitos)"></a></p><br/><br/><p><em>1/10 en binario (primeros 1369 dígitos)</em></p><br/><br/><p>Si suponemos que nuestro ordenador es capaz de almacenar hasta 53 dígitos, una vez truncado nuestro 0.1 queda representado en binario como:</p><br/><br/><p>0.0001100110011001100110011001100110011001100110011001101</p><br/><br/><p>...que en decimal es</p><br/><br/><p>0.1000000000000000055511151231257827021181583404541015625</p><br/><br/><p>Para este problema hay básicamente dos soluciones:</p><br/><br/><ul><br/><li>Usar un tipo decimal exacto en vez de coma flotante. Hay lenguajes que proporcionan estos tipos nativamente (por ejemplo, .NET tiene el tipo <a href="https://msdn.microsoft.com/en-us/library/364x0z75.aspx">decimal</a>); para los que no, suele haber librerías especializadas para ello (por ejemplo <a href="https://github.com/MikeMcl/decimal.js">decimal.js</a> para Javascript).</li><br/><li>Si el número de decimales se conoce por adelantado (por ejemplo al tratar con valores monetarios), los valores se pueden representar como enteros. Así, 123.45€ se representaría como 12345 céntimos. El punto decimal se añadiría al final, a la hora de mostrar el valor al usuario.</li><br/></ul><br/><br/><p>Un buen sitio con más información sobre este tema: <a href="http://puntoflotante.org">http://puntoflotante.org</a></p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 3,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2015, 12, 2, 7, 43, 50, 70000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2015, 12, 2, 9, 56, 34, 630000),
#   'LastEditDate': datetime.datetime(2015, 12, 2, 9, 56, 34, 630000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 23,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 23,
#   'ParentId': 197,
#   'PostTypeId': 2,
#   'Score': 195,
#   'Tags': '',
#   'Title': '',
#   'ViewCount': '',
#   'owner': [{'_id': ObjectId('67c9e6c002ff02b3f2846123'),
#     'Id': 23,
#     'AboutMe': '<p>Empecemos por lo importante: me encantan los <a href="http://en.wikipedia.org/wiki/MSX" rel="nofollow noreferrer">ordenadores MSX</a> y el <a href="https://en.wikipedia.org/wiki/Renault_Twingo#Twingo_I_.281993.E2.80.932007.29" rel="nofollow noreferrer">Renault Twingo clásico</a> (sólo el modelo 1993-2007; los modelos más nuevos son tan aburridos como cualquier otro coche).<br/></p><br/><p>Y ahora la parte aburrida. Soy ingeniero de telecomunicaciones pero trabajo como programador, principalmente en C#. He hecho mucho desarrollo en Windows Forms en el pasado, también WPF y Silverlight, pero ahora estoy más metido en el desarrollo web (al principio sólo backend, pero ahora estoy en el mundo del frontend también).<br/></p><br/><p><del>Cuando tengo tiempo libre me gusta</del> Cuando <em>tenía</em> tiempo libre me gustaba programar mi MSX Turbo-R en ensamblador de Z80. De hecho he desarrollado incluso <a href="http://konamiman.com/msx/msx-s.html#inl" rel="nofollow noreferrer">una pila TCP/IP completa para MSX</a> (<a href="https://bitbucket.org/konamiman/msx/src/cf8fc0cc652e1ff79b1a2fc657b2f10d4e0c72fb/SRC/INL/?at=default" rel="nofollow noreferrer">las fuentes están disponibles</a>, ¡échales un ojo!), que presenté como mi proyecto de final de carrera en la universidad, con muy buenos resultados.</p><br/><p>Puedes ver mis proyectos de software aquí:<br/><br/><a href="http://www.konamiman.com" rel="nofollow noreferrer">http://www.konamiman.com</a><br/><br/><a href="http://github.com/konamiman" rel="nofollow noreferrer">http://github.com/konamiman</a></p><br/><p>Y si quieres puedes escribirme: konamiman@konamiman.com</p><br/>',
#     'AccountId': 3201,
#     'CreationDate': datetime.datetime(2015, 10, 29, 14, 53, 36, 233000),
#     'DisplayName': 'Konamiman',
#     'DownVotes': 4,
#     'LastAccessDate': datetime.datetime(2023, 11, 13, 20, 49, 46, 673000),
#     'Location': 'Palma de Mallorca, Spain',
#     'Reputation': 5278,
#     'UpVotes': 367,
#     'Views': 787,
#     'WebsiteUrl': 'http://www.konamiman.com'}]},
#  {'_id': ObjectId('67c9e68702ff02b3f27e5694'),
#   'Id': 18232,
#   'AcceptedAnswerId': 18233,
#   'AnswerCount': 6,
#   'Body': '<p>Las sentencias dinámicas son sentencias SQL que se crean como cadenas de texto (strings) y en las que se insertan/concatenan valores obtenidos de alguna fuente (normalmente proveniente del usuario), lo que puede hacer que sean vulnerables a inyección SQL si no se sanean las entradas, como por ejemplo:</p><br/><br/><pre><code>$id_usuario = $_POST["id"];<br/><br/>mysql_query("SELECT * FROM usuarios WHERE id = $id_usuario");<br/></code></pre><br/><br/><p>Eso es un ejemplo de una vulnerabilidad grave en la seguridad de una aplicación (web o no) porque si el usuario introdujese un valor como <code>1; DROP TABLE usuarios;--</code> nos encontraríamos con que la sentencia ejecutada sería:</p><br/><br/><pre><code>SELECT * FROM usuarios WHERE id = 1; DROP TABLE usuarios;--<br/></code></pre><br/><br/><p>Y se eliminaría la tabla Usuarios con todos los datos contenidos en ella. </p><br/><br/><p><strong>¿Cómo puedo evitar que la inyección SQL ocurra en PHP?</strong></p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 1,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2016, 7, 31, 21, 3, 26, 190000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2023, 5, 16, 22, 14, 53, 633000),
#   'LastEditDate': datetime.datetime(2017, 3, 4, 3, 8, 9, 33000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 29967,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 250,
#   'ParentId': '',
#   'PostTypeId': 1,
#   'Score': 232,
#   'Tags': '<php><mysql><sql><seguridad><inyección-sql>',
#   'Title': '¿Cómo evitar la inyección SQL en PHP?',
#   'ViewCount': 77113,
#   'owner': [{'_id': ObjectId('67c9e6c002ff02b3f28461f4'),
#     'Id': 250,
#     'AboutMe': '<p>Ingeniero Software con experiencia en diferentes lenguajes y tecnologías. Moderador electo de Stack Overflow en español desde 2017.</p><br/><br/><p>En mi tiempo libre me gusta jugar con tecnologías web y, en particular, hacer pequeñas cosas en HTML y CSS (sin JavaScript). Como por ejemplo esta <a href="https://codepen.io/alvaromontoro/full/WZZNPR" rel="nofollow noreferrer">pila Duracell</a>, un <a href="https://codepen.io/alvaromontoro/full/jGLOBy" rel="nofollow noreferrer">juego de preguntas</a>, un <a href="https://codepen.io/alvaromontoro/full/Nwgarb/" rel="nofollow noreferrer">reloj textual</a>, o un <a href="https://codepen.io/alvaromontoro/full/OwwQMm/" rel="nofollow noreferrer">juego de mesa completo: Serpientes y Escaleras</a>.</p><br/><br/><hr><br/><br/><p>Enlace a mi <a href="https://www.linkedin.com/in/alvaromontoro/" rel="nofollow noreferrer">perfil profesional de LinkedIn</a>. Si me añades como conexión, añade una nota con tu nombre en Stack Overflow para saber quién eres.</p><br/>',
#     'AccountId': 4550651,
#     'CreationDate': datetime.datetime(2015, 12, 1, 18, 7, 59, 433000),
#     'DisplayName': 'Alvaro Montoro',
#     'DownVotes': 1312,
#     'LastAccessDate': datetime.datetime(2023, 12, 1, 18, 9, 25, 387000),
#     'Location': 'Austin, TX',
#     'Reputation': 49245,
#     'UpVotes': 3420,
#     'Views': 7610,
#     'WebsiteUrl': 'http://www.alvaromontoro.com'}]},
#  {'_id': ObjectId('67c9e68702ff02b3f27e5695'),
#   'Id': 18233,
#   'AcceptedAnswerId': '',
#   'AnswerCount': '',
#   'Body': '<blockquote><br/><h1>NO USES SENTENCIAS DINÁMICAS NI FUNCIONES <code>mysql_*</code></h1><br/><p>Las funciones <code>mysql_*</code> (<code>mysql_connect</code>, <code>mysql_query</code>, etc.) son inseguras por naturaleza y su uso no sólo no está recomendado, sino que <strong>se consideran obsoletas y se han eliminado completamente a partir de PHP7</strong>.</p><br/><p>Incluso los métodos nativos que existen en PHP para sanear las entradas de usuario (como <code>mysql_real_escape_string</code>) pueden presentar (raros) problemas y fallar en algunos casos como cuando se usan codificación de caracteres diferentes a UTF-8 junto a versiones no actualizadas de MySQL (en las <a href="http://php.net/manual/es/mysqli.real-escape-string.php" rel="noreferrer">páginas de PHP para estas funciones</a> se avisa de este riesgo).</p><br/></blockquote><br/><hr /><br/><h1>Usa sentencias preparadas y consultas parametrizadas</h1><br/><p>Aunque se podrían sanear las entradas usando métodos como <code>mysqli_real_escape_string</code>, es más recomendable la utilización de sentencias preparadas o parametrizadas. Las sentencias preparadas te permitirán ejecutar la misma sentencia con gran eficiencia.</p><br/><p>En PHP, tienes dos alternativas principales: <a href="https://www.php.net/manual/es/book.pdo.php" rel="noreferrer">PDO</a> y  <a href="https://www.php.net/manual/es/book.mysqli.php" rel="noreferrer">MySQLi</a>. Hay varias diferencias entre ambas, pero la principal es que PDO se puede usar con diferentes tipos de base de datos (<a href="https://www.php.net/manual/es/intro.pdo.php#intro.pdo" rel="noreferrer">dependiendo del driver utilizado</a>) mientras que MySQLi es exclusivamente para bases de datos MySQL. Es por ello que recomendaría PDO sobre MySQLi.</p><br/><h2>PDO</h2><br/><p>Los <a href="https://www.php.net/manual/es/pdo.prepare.php#refsect1-pdo.prepare-description" rel="noreferrer">marcadores de posición</a> (que indican dónde se sustituirá una cadena por su valor), se pueden definir bien usando un signo de interrogación (<code>?</code>) o bien usando un nombre (generalmente empezando con <code>:</code>). Personalmente prefiero usar un nombre, porque eso me ayuda a encontrar posibles errores en caso de tener múltiples variables.</p><br/><p>Aquí dejo un ejemplo para el código de la pregunta:</p><br/><pre><code>// la variable $pdo contendrá el objeto con la conexión PDO<br/>$pdo = new PDO(\'mysql:host=mihost;dbname=basedatos\', "usuario", "contraseña");<br/><br/>$id_usuario = $_POST["id"];<br/><br/>$sentencia = $pdo->prepare("SELECT * FROM usuarios WHERE id = :idusuario");<br/>$sentencia=$pdo->setAttribute(PDO::ATTR_EMULATE_PREPARES, false);<br/>$sentencia->bindParam(":idusuario", $id_usuario, PDO::PARAM_INT);<br/>$sentencia->execute();<br/></code></pre><br/><p>En este caso, <code>:idusuario</code> se sustituirá por el valor de <code>$_POST["id"]</code> de forma segura, y cuando hace el <em>bind</em> se indica que la variable es de tipo entero (<code>PDO::PARAM_INT</code>).</p><br/><blockquote><br/><p>Nota: si la variable es una cadena de texto se usará <code>PDO::PARAM_STR</code> y no hace falta poner las comillas en la sentencia SQL; al especificarle a PHP que es una cadena, las añadirá automáticamente al hacer el <em>bind</em>.</p><br/></blockquote><br/><p>En caso de que existan varias variables a incluir en la sentencia SQL, se debe incluir un único parámetro para cada uno de los valores que se usan en la sentencia. Del ejemplo anterior, el <code>:idusuario</code> puede usarse una única vez en la consulta que se esta preparando. Si fuera necesario usar el "idusuario" de nuevo en la consulta, se debe crear otro parámetro con el valor de <code>$id_usuario</code>.</p><br/><pre><code>$pdo = new PDO(\'mysql:host=mihost;dbname=basedatos\', "usuario", "contraseña");<br/><br/>$id_usuario = $_POST["id"];<br/>    <br/>$sentencia = $pdo->prepare("UPDATE usuarios SET id = :idusuario WHERE id = :idusuario1");<br/>$sentencia=$pdo->setAtt ...
#   'ClosedDate': None,
#   'CommentCount': 4,
#   'CommunityOwnedDate': datetime.datetime(2016, 7, 31, 21, 3, 26, 190000),
#   'ContentLicense': 'CC BY-SA 4.0',
#   'CreationDate': datetime.datetime(2016, 7, 31, 21, 3, 26, 190000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2022, 8, 13, 1, 55, 39, 97000),
#   'LastEditDate': datetime.datetime(2022, 8, 13, 1, 55, 39, 97000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 195444,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 250,
#   'ParentId': 18232,
#   'PostTypeId': 2,
#   'Score': 219,
#   'Tags': '',
#   'Title': '',
#   'ViewCount': '',
#   'owner': [{'_id': ObjectId('67c9e6c002ff02b3f28461f4'),
#     'Id': 250,
#     'AboutMe': '<p>Ingeniero Software con experiencia en diferentes lenguajes y tecnologías. Moderador electo de Stack Overflow en español desde 2017.</p><br/><br/><p>En mi tiempo libre me gusta jugar con tecnologías web y, en particular, hacer pequeñas cosas en HTML y CSS (sin JavaScript). Como por ejemplo esta <a href="https://codepen.io/alvaromontoro/full/WZZNPR" rel="nofollow noreferrer">pila Duracell</a>, un <a href="https://codepen.io/alvaromontoro/full/jGLOBy" rel="nofollow noreferrer">juego de preguntas</a>, un <a href="https://codepen.io/alvaromontoro/full/Nwgarb/" rel="nofollow noreferrer">reloj textual</a>, o un <a href="https://codepen.io/alvaromontoro/full/OwwQMm/" rel="nofollow noreferrer">juego de mesa completo: Serpientes y Escaleras</a>.</p><br/><br/><hr><br/><br/><p>Enlace a mi <a href="https://www.linkedin.com/in/alvaromontoro/" rel="nofollow noreferrer">perfil profesional de LinkedIn</a>. Si me añades como conexión, añade una nota con tu nombre en Stack Overflow para saber quién eres.</p><br/>',
#     'AccountId': 4550651,
#     'CreationDate': datetime.datetime(2015, 12, 1, 18, 7, 59, 433000),
#     'DisplayName': 'Alvaro Montoro',
#     'DownVotes': 1312,
#     'LastAccessDate': datetime.datetime(2023, 12, 1, 18, 9, 25, 387000),
#     'Location': 'Austin, TX',
#     'Reputation': 49245,
#     'UpVotes': 3420,
#     'Views': 7610,
#     'WebsiteUrl': 'http://www.alvaromontoro.com'}]},
#  {'_id': ObjectId('67c9e69202ff02b3f27f1f4b'),
#   'Id': 87842,
#   'AcceptedAnswerId': '',
#   'AnswerCount': '',
#   'Body': '<p>Hola, mi nombre es Álvaro Montoro, soy un Ingeniero Informático español aunque actualmente vivo y trabajo en los Estados Unidos, en la capital del estado de Texas: Austin.</p><br/><br/><p>Tengo experiencia en diferentes ámbitos de programación: back-end, front-end, bases de datos, seguridad... y en bastantes lenguajes: PHP, Java, C#, Visual Basic, C/C++, JavaScript... lo que hace que me mueva por un grupo variado de etiquetas (aunque prefiera las de programación web) y se refleja en la medalla <a href="https://es.stackoverflow.com/help/badges/15/generalist"><code>generalista</code></a> (de momento el único que la tiene).</p><br/><br/><p>Pros:</p><br/><br/><ul><br/><li>Paso bastante tiempo en SOes (he visitado el sitio 594 días, 384 consecutivos ).</li><br/><li>He estado en el sitio desde Area 51 y cuento con experiencia en otros sitios de SE (no como moderador).</li><br/><li>Me gusta guiarme por las reglas del Centro de Ayuda.</li><br/></ul><br/><br/><p>Contras:</p><br/><br/><ul><br/><li>Aunque activo en chat y meta, debería ser más activo.</li><br/><li>Cuento con experiencia en otros sitios de SE, lo que hace que a veces use la misma vara de medir que usaría en otros sitios.</li><br/><li>Me gusta guiarme por las reglas del Centro de Ayuda... y a veces hay que ser más paciente y flexible.</li><br/></ul><br/>',
#   'ClosedDate': None,
#   'CommentCount': 12,
#   'CommunityOwnedDate': datetime.datetime(2017, 7, 18, 20, 7, 26, 473000),
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2017, 7, 18, 20, 7, 26, 473000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2017, 7, 20, 15, 58, 45, 867000),
#   'LastEditDate': datetime.datetime(2017, 7, 20, 15, 58, 45, 867000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 250,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 250,
#   'ParentId': '',
#   'PostTypeId': 6,
#   'Score': 173,
#   'Tags': '',
#   'Title': '',
#   'ViewCount': '',
#   'owner': [{'_id': ObjectId('67c9e6c002ff02b3f28461f4'),
#     'Id': 250,
#     'AboutMe': '<p>Ingeniero Software con experiencia en diferentes lenguajes y tecnologías. Moderador electo de Stack Overflow en español desde 2017.</p><br/><br/><p>En mi tiempo libre me gusta jugar con tecnologías web y, en particular, hacer pequeñas cosas en HTML y CSS (sin JavaScript). Como por ejemplo esta <a href="https://codepen.io/alvaromontoro/full/WZZNPR" rel="nofollow noreferrer">pila Duracell</a>, un <a href="https://codepen.io/alvaromontoro/full/jGLOBy" rel="nofollow noreferrer">juego de preguntas</a>, un <a href="https://codepen.io/alvaromontoro/full/Nwgarb/" rel="nofollow noreferrer">reloj textual</a>, o un <a href="https://codepen.io/alvaromontoro/full/OwwQMm/" rel="nofollow noreferrer">juego de mesa completo: Serpientes y Escaleras</a>.</p><br/><br/><hr><br/><br/><p>Enlace a mi <a href="https://www.linkedin.com/in/alvaromontoro/" rel="nofollow noreferrer">perfil profesional de LinkedIn</a>. Si me añades como conexión, añade una nota con tu nombre en Stack Overflow para saber quién eres.</p><br/>',
#     'AccountId': 4550651,
#     'CreationDate': datetime.datetime(2015, 12, 1, 18, 7, 59, 433000),
#     'DisplayName': 'Alvaro Montoro',
#     'DownVotes': 1312,
#     'LastAccessDate': datetime.datetime(2023, 12, 1, 18, 9, 25, 387000),
#     'Location': 'Austin, TX',
#     'Reputation': 49245,
#     'UpVotes': 3420,
#     'Views': 7610,
#     'WebsiteUrl': 'http://www.alvaromontoro.com'}]}]

# %% [markdown]
# ### `$arrayElemAt`
#
# El `$lookup` genera un _array_ con todos los resultados. El operador `$arrayElementAt` accede al primer elemento.

# %%
respuestas: CommandCursor[dict[str, Any]] = db.posts.aggregate( [
    {'$match': { 'Score' : {'$gte': 150}}},
    {'$lookup': {
        'from': "users",
        'localField': "OwnerUserId",
        'foreignField': "Id",
        'as': "owner"}
    },
    { '$project' : {
        'Id' : True,
        'Score' : True,
        'username' : {'$arrayElemAt' : ['$owner.DisplayName', 0]},
        'owner.DisplayName' : True
      }}
    ])
list(respuestas)
# Out:
# [{'_id': ObjectId('67c9e68502ff02b3f27e1e46'),
#   'Id': 40,
#   'Score': 206,
#   'owner': [{'DisplayName': 'jachguate'}],
#   'username': 'jachguate'},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1ec6'),
#   'Id': 197,
#   'Score': 176,
#   'owner': [{'DisplayName': 'Peter Olson'}],
#   'username': 'Peter Olson'},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1eca'),
#   'Id': 204,
#   'Score': 195,
#   'owner': [{'DisplayName': 'Konamiman'}],
#   'username': 'Konamiman'},
#  {'_id': ObjectId('67c9e68702ff02b3f27e5694'),
#   'Id': 18232,
#   'Score': 232,
#   'owner': [{'DisplayName': 'Alvaro Montoro'}],
#   'username': 'Alvaro Montoro'},
#  {'_id': ObjectId('67c9e68702ff02b3f27e5695'),
#   'Id': 18233,
#   'Score': 219,
#   'owner': [{'DisplayName': 'Alvaro Montoro'}],
#   'username': 'Alvaro Montoro'},
#  {'_id': ObjectId('67c9e69202ff02b3f27f1f4b'),
#   'Id': 87842,
#   'Score': 173,
#   'owner': [{'DisplayName': 'Alvaro Montoro'}],
#   'username': 'Alvaro Montoro'}]

# %% [markdown]
# ### `$unwind`
#
# Este operador *desdobla* cada fila por cada elemento del array.
#
# Ej: El siguiente código:
#
# ```python
# db.inventario.insert_one({ "_id" : 1, "item" : "ABC1", "tallas": [ "S", "M", "L"] })
# db.inventario.aggregate( [ { "$unwind" : "$tallas" } ] )
# ```
#
# Devolverá:
#
# ```json
# { "_id" : 1, "item" : "ABC1", "tallas" : "S" }
# { "_id" : 1, "item" : "ABC1", "tallas" : "M" }
# { "_id" : 1, "item" : "ABC1", "tallas" : "L" }
# ```
#
# En el ejemplo de procesamiento de posts que estamos llevando a cabo, como sabemos que el array `$owner` sólo contiene un elemento, sólo habrá una fila por fila original, pero sin el _array_. Finalmente se puede proyectar el campo que se quiera. En este caso el `ownerDisplayName` que es proyectado (renombrado) como `username`.

# %%
respuestas: CommandCursor[dict[str, Any]] = db.posts.aggregate( [
    { '$match': { 'Score' : {'$gte': 150}}},
    { '$lookup': {
        'from': "users",
        'localField': "OwnerUserId",
        'foreignField': "Id",
        'as': "owner"
      }
    },
    { '$unwind': '$owner'},
    { '$project' : {
          'username': '$owner.DisplayName'
      }
    }
    ])
list(respuestas)
# Out:
# [{'_id': ObjectId('67c9e68502ff02b3f27e1e46'), 'username': 'jachguate'},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1ec6'), 'username': 'Peter Olson'},
#  {'_id': ObjectId('67c9e68502ff02b3f27e1eca'), 'username': 'Konamiman'},
#  {'_id': ObjectId('67c9e68702ff02b3f27e5694'), 'username': 'Alvaro Montoro'},
#  {'_id': ObjectId('67c9e68702ff02b3f27e5695'), 'username': 'Alvaro Montoro'},
#  {'_id': ObjectId('67c9e69202ff02b3f27f1f4b'), 'username': 'Alvaro Montoro'}]

# %% [markdown]
# ### `$push`
#
# Devuelve un array con *todos* los valores que resultan de aplicar una determinada expresión a los documentos que forman parte del pipeline.
#
# Obtener el listado con el identificador de `Posts` (`Id`) asociados a cada valor de `Score`.

# %%
posts_by_score: CommandCursor[dict[str, Any]] = db.posts.aggregate([
    { '$limit': 2000 },
    {
        '$group':{
            '_id': '$Score',
            'posts':{
                '$push': {
                    'post': '$Id'
                }
            }
        }
    }

])
list(posts_by_score)
# Out:
# [{'_id': 124, 'posts': [{'post': 331}]},
#  {'_id': 68, 'posts': [{'post': 245}]},
#  {'_id': 56, 'posts': [{'post': 1488}]},
#  {'_id': 33, 'posts': [{'post': 621}, {'post': 938}]},
#  {'_id': 111, 'posts': [{'post': 151}]},
#    {'post': 851},
#    {'post': 916},
#    {'post': 940},
#    {'post': 942},
#    {'post': 950},
#    {'post': 954},
#    {'post': 968},
#    {'post': 970},
#    {'post': 1000},
#    {'post': 1012},
#    {'post': 1016},
#    {'post': 1069},
#    {'post': 1164},
#    {'post': 1222},
#    {'post': 1247},
#    {'post': 1296},
#    {'post': 1308},
#    {'post': 1320},
#    {'post': 1335},
#    {'post': 1342},
#    {'post': 1377},
#    {'post': 1378},
#    {'post': 1412},
#    {'post': 1494},
#    {'post': 1496},
#    {'post': 1506},
#    {'post': 1642},
#    {'post': 1652},
#    {'post': 1727},
#    {'post': 1748},
#    {'post': 1780},
#    {'post': 1826},
#    {'post': 1829},
#    {'post': 1889},
#    {'post': 1914},
#    {'post': 1957},
#    {'post': 1964},
#    {'post': 2016},
#    {'post': 2057},
#    {'post': 2152},
#    {'post': 2168},
#    {'post': 2244}]},
#  {'_id': 14,
#   'posts': [{'post': 8},
#    {'post': 27},
#    {'post': 80},
#    {'post': 332},
#    {'post': 356},
#    {'post': 364},
#    {'post': 422},
#    {'post': 558},
#    {'post': 569},
#    {'post': 591},
#    {'post': 660},
#    {'post': 935},
#    {'post': 1015},
#    {'post': 1071},
#    {'post': 1184},
#    {'post': 1272},
#    {'post': 1448},
#    {'post': 1869},
#    {'post': 1952},
#    {'post': 1953},
#    {'post': 1960}]}]

# %% [markdown]
# ### `$addToSet`
#
#  Devuelve un array de todos los valores únicos que resultan de aplicar una expresión a cada documento de un grupo.
#
#
# Vamos a obtener el listado de `Tags` asociadas a cada tipo de licencia  `ContentLicense`.

# %%
license_and_tags: CommandCursor[dict[str, Any]] = db.posts.aggregate([
    { "$match" : {"PostTypeId": 1}},
    {"$limit": 1000},

    {'$group':{
            '_id':'$ContentLicense',
            'AllTags': { '$addToSet': "$Tags" }
        }
    }
])
list(license_and_tags)
# Out:
# [{'_id': 'CC BY-SA 4.0',
#   'AllTags': ['<javascript><validación><email><regex>',
#    '<python><djangorestframework><django-models>',
#    '<c#>',
#    '<java><android><android-intent><android-asynctask>',
#    '<select2><yii><yiibooster><cache>',
#    '<git><git-merge>',
#    '<xml>',
#    '<archivo><fish><exists>',
#    '<sql-server><asp.net-mvc-5>',
#    '<javascript><hapijs>',
#    '<python><django><python-2.7><utf-8><codificación>',
#    '<python><pip><pillow>',
#    '<python><bootstrap><django><python-3.x><select2>',
#    '<java>',
#    '<javascript><google-apps-script><google-hoja-de-cálculo>',
#    '<python><python-2.7>',
#    '<android><android-studio>',
#    '<php><html><api>',
#    '<php><mysqli>',
#    '<bash><verilog>',
#    '<c#><.net><entity-framework><asp.net-core><model-view-controller>',
#    '<python><django><django-models><base-de-datos>',
#    '<c++><c++11>',
#    '<python><django><python-3.x>',
#    '<java><android>',
#    '<python><django>',
#    '<javascript><jquery><asincronismo>',
#    '<git><git-push>',
#    '<base-de-datos><cálculo-relacional>',
#    '<nodejs><loopback>',
#    '<java><android><navigationview>',
#    '<licencias><código-abierto>',
#    '<c#><sql-server><windows-forms>',
#    '<c#><asp.net><excel>',
#    '<asp.net><asp.net-mvc><librería><bower>',
#    '<javascript><jquery><asp.net-mvc>',
#    '<c#><reflexión>',
#    '<java><ordenamiento><lista>',
#    '<c#><ofuscación>',
#    '<java><java-swing>',
#    '<java><seguridad><ingeniería-inversa>',
#    '<javascript>',
#    '<python><python-3.x>',
#    '<raku>',
#    '<javascript><clausuras>',
#    '<mysql><sql><join>',
#    '<.net><asp.net-web-api><asp.net>']},
#  {'_id': 'CC BY-SA 3.0',
#   'AllTags': ['<c#><xaml><uwp><mvvm>',
#    '<sql-server>',
#    '<bash><linux>',
#    '<r><ggplot2>',
#    '<php><sql><mysql><phpmyadmin><mysqli>',
#    '<laravel><laravel-5>',
#    '<archivo><linux><rsync>',
#    '<ios><xcode>',
#    '<python><ide><pycharm>',
#    '<html>',
#    '<django><api><djangorestframework><permisos>',
#    '<archivo><unix><grep><ascii>',
#    '<python><django><python-2.7>',
#    '<algoritmos><lenguaje-agnóstico><loops><condiciones>',
#    '<python><django><django-models>',
#    '<javascript><html5><css>',
#    '<javascript><jquery><angularjs><angular-directivas>',
#    '<c#><asp.net-mvc><asp.net-web-api>',
#    '<c#><conversión-de-tipos><tipos>',
#    '<angularjs-2.0><typescript><system.js>',
#    '<asp.net><oauth><rest>',
#    '<swift2>',
#    '<html><asp.net><vb.net>',
#    '<java><dukescript>',
#    '<javascript><babeljs>',
#    '<json><asp.net><ajax><vb.net>',
#    '<android><admob>',
#    '<sequelize.js><pruebas-unitarias>',
#    '<c++><c++11>',
#    '<javascript><poo>',
#    '<android><android-softkeyboard>',
#    '<python><django><python-3.x>',
#    '<django><django-models>',
#    '<sharepoint><powershell>',
#    '<android><android-layout>',
#    '<go>',
#    '<haskell>',
#    '<php><apache>',
#    '<javascript><android><ajax><cordova><jquery-mobile>',
#    '<javascript><jquery><requirejs>',
#    '<java><paso-por-valor><paso-por-referencia>',
#    '<javascript><jquery><tinymce>',
#    '<javascript><android><reactjs><react-native>',
#    '<jquery><css>',
#    '<archivo><windows><consola><proceso>',
#    '<git><conflictos>',
#    '<html5><bootstrap>',
#    '<python><python-2.7><funciones>',
#    '<html5><bootstrap><apache>',
#    '<php><array>',
#    '<matemáticas><coma-flotante><lenguaje-agnóstico>',
#    '<c#><sql><sql-server><entity-framework><code-first>',
#    '<xaml><uwp>',
#    '<c#><xaml><uwp>',
#    '<python><variables>',
#    '<css><html5><css3><3d><importación>',
#    '<c><hilos>',
#    '<jquery><ajax><laravel-5>',
#    '<javascript><kendoui><knockoutjs>',
#    '<string><c#>',
#    '<swift><swift2>',
#    '<ios><swift2><objective-c>',
#    '<asp.net-web-api>',
#    '<asp>',
#    '<c++><visual-studio-2010>',
#    '<ios><jquery><cordova>',
#    '<css><css3><filtros-css>',
#    '<javascript><bootstrap><bootstrap-carousel>',
#    '<c#><hilos>',
#    '<c#><linq>',
#    '<python><numpy><array>',
#    '<android-studio><ubuntu><java>',
#    '<oracle><oracle-11g>',
#    '<entity-framework><linq>',
#    '<c#><windows-forms><bitmap>',
#    '<postgresql><debian>',
#    '<android>',
#    '<c#><jquery><ajax><asp.net-mvc-5><asp.net-mvc>',
#    '<javascript><java><jquery>',
#    '<java><android><android-layout>',
#    '<bash><regex>',
#    '<c#><jquery><html><ajax>',
#    '<python><django><formularios>',
#    '<php><angularjs><http><binding><servicio>',
#    '<sql-server><postgresql>',
#    '<javascript><momentjs><underscorejs>',
#    '<entity-framework><linq-to-sql><dbml>',
#    '<spring><spring-roo><gvnix>',
#    '<visual-studio>',
#    '<google-apps-script><google-hoja-de-cálculo><optimización>',
#    '<c#><asp.net><sql-server>',
#    '<c#><xaml><uwp><sqlite3><binding>',
#    '<apache><.htaccess><redirección><reescritura-url><mod-rewrite>',
#    '<php><sql>',
#    '<javascript><highcharts>',
#    '<php><doctrine><doctrine2>',
#    '<string><php><str-replace>',
#    '<python><string><ordenamiento>',
#    '<go><tipos>',
#    '<mysql><phpmyadmin>',
#    '<google-app-engine>',
#    '<java><spring><test-ng>',
#    '<jquery><ajax><asp.net-mvc-5>',
#    '<c#><asp.net><azure>',
#    '<c#><jquery><asp.net-mvc-5><asp.net>',
#    '<html><email><google-chrome>',
#    '<lista><elixir>',
#    '<regex><notepad++>',
#    '<reescritura-url><mod-rewrite>',
#    '<wolfram-mathematica>',
#    '<programación-funcional><haskell><estructuras-de-datos>',
#    '<php><poo>',
#    '<javascript><jquery><api><google-drive>',
#    '<android><android-studio>',
#    '<visual-studio><azure><visual-studio-2015>',
#    '<python><django><django-models><users-roles>',
#    '<java><drools><rabbit-mq>',
#    '<php><ajax><laravel><laravel-5>',
#    '<java><eclipse><swt>',
#    '<java><genexus>',
#    '<java><io>',
#    '<string><c>',
#    '<javascript><json><xml>',
#    '<java><android><avd>',
#    '<soap><soapui><wcf><servicio>',
#    '<java><primefaces>',
#    '<java><android><google-maps>',
#    '<java><thymeleaf>',
#    '<php><mysql><sql>',
#    '<java><firebird>',
#    '<java><spring-mvc><thymeleaf>',
#    '<javascript><html5><bootstrap>',
#    '<python>',
#    '<netbeans>',
#    '<python><django><ec2>',
#    '<yii>',
#    '<python><conda>',
#    '<asp.net-mvc><linq>',
#    '<sql><visual-studio-2013>',
#    '<c#><entity-framework>',
#    '<javascript><nodejs>',
#    '<javascript><jquery><html><css>',
#    '<ruby><ruby-on-rails>',
#    '<javascript><android><swift><objective-c><uiwebview>',
#    '<c#><.net><visual-studio>',
#    '<paso-por-valor><paso-por-referencia><lenguaje-agnóstico>',
#    '<python><django><ordenamiento>',
#    '<css><less>',
#    '<java><android>',
#    '<nginx><angularjs>',
#    '<mysql><java><spring><hibernate>',
#    '<c#>',
#    '<jquery><html><youtube>',
#    '<java><c++><punteros>',
#    '<c#><uwp>',
#    '<bash>',
#    '<python><python-3.x><poo>',
#    '<android><json>',
#    '<nginx><logrotate><configuración>',
#    '<sql><ms-access-2010>',
#    '<jquery><django><django-models><ajax>',
#    '<javascript><underscorejs>',
#    '<javascript><json><angularjs>',
#    '<java><android><gradle>',
#    '<linux><apache>',
#    '<javascript><bookmarklet><gmail>',
#    '<android><cordova><ionic>',
#    '<oracle><sqlfiddle>',
#    '<java><hashmap>',
#    '<jquery><django><ajax>',
#    '<ruby><bundler><gemfile>',
#    '<sql><asp.net-mvc-5><azure>',
#    '<asp.net><asp.net-mvc-5><razor>',
#    '<spring-tool-suite>',
#    '<html><css>',
#    '<javascript><array>',
#    '<java><dukescript><admob>',
#    '<c++><string>',
#    '<html><asp.net><bootstrap>',
#    '<unix><dup>',
#    '<c#><mysql><genexus>',
#    '<ios><swift><swift2>',
#    '<javascript><google-maps>',
#    '<php><yii2>',
#    '<java><sql><oracle><jdbc>',
#    '<nodejs><mongodb><express>',
#    '<c#><unity3d>',
#    '<python><django><nginx>',
#    '<c#><asp.net-mvc-5><razor>',
#    '<python><punteros>',
#    '<abap>',
#    '<c#><asp.net><asp.net-mvc><google-maps>',
#    '<ios><swift2><xcode>',
#    '<ios><swift2>',
#    '<html5><css3><bootstrap><wordpress>',
#    '<.net><clickonce><deployment>',
#    '<python><archivo>',
#    '<php><mysql>',
#    '<hilos>',
#    '<javascript><html><json><knockoutjs>',
#    '<javascript><google-apps-script><google-hoja-de-cálculo><google-forms>',
#    '<linux><grep>',
#    '<javascript><jquery><html5>',
#    '<ios><midi>',
#    '<as400>',
#    '<windows-forms>',
#    '<php><mysql><bootstrap>',
#    '<java><postgresql>',
#    '<javascript><d3.js>',
#    '<c++><c++98>',
#    '<javascript><jquery><typescript>',
#    '<vb.net>',
#    '<css><sass><scss><webpack>',
#    '<javascript><jquery><dom>',
#    '<php><joomla3>',
#    '<javascript><nodejs><pm2>',
#    '<java><oracle><base64>',
#    '<ajax><vb.net>',
#    '<wordpress>',
#    '<javascript><jquery>',
#    '<c#><email><visual-studio-2015>',
#    '<javascript><jquery><html>',
#    '<genexus><devices>',
#    '<excel>',
#    '<ios><swift><objective-c>',
#    '<c#><linq><excel>',
#    '<conda>',
#    '<java><windows>',
#    '<vb.net><windows-forms>',
#    '<javascript><jquery><angularjs>',
#    '<wpf><xaml>',
#    '<java><hibernate>',
#    '<bootstrap><ruby-on-rails><ruby>',
#    '<c#><.net>',
#    '<python><python-2.7><web2py>',
#    '<javascript><google-apps-script><google-hoja-de-cálculo><google-forms><google-documentos>',
#    '<jquery><html>',
#    '<python><python-3.x><datetime>',
#    '<python><python-3.x><pdf><reportlab>',
#    '<git><visual-studio><nodejs><azure>',
#    '<c#><http><asp.net-web-api>',
#    '<android><3d>',
#    '<clojure>',
#    '<jsf>',
#    '<regex><google-hoja-de-cálculo>',
#    '<javascript><angularjs><nodejs>',
#    '<python><ponyorm>',
#    '<html5><ajax><vb.net>',
#    '<python><matemáticas>',
#    '<ssms>',
#    '<java><apache-poi>',
#    '<java><java-ee><servlets>',
#    '<css><jsfiddle><scss>',
#    '<php><html>',
#    '<ios><objective-c><swift>',
#    '<git><github><github-pages>',
#    '<java><base-de-datos><archivo-de-propiedades>',
#    '<oracle><oracle-11g><sqlfiddle>',
#    '<c#><xaml><wpf>',
#    '<seo>',
#    '<java><android><linux><windows>',
#    '<ios><swift>',
#    '<directorioactivo><office365><smartcard><adfs>',
#    '<javascript><html><asp>',
#    '<javascript><php><html5>',
#    '<linux>',
#    '<python><django><python-3.x><celery>',
#    '<sql><oracle><oracle-11g>',
#    '<javascript><jquery><json>',
#    '<java><java-ee>',
#    '<python><imagen>',
#    '<mysql><linux><gpg>',
#    '<windows><directorioactivo><windows10><registro-windows>',
#    '<c++><c>',
#    '<c#><.net><windows>',
#    '<bash><shell>',
#    '<javascript><json><string>',
#    '<javascript><jquery><knockoutjs>',
#    '<html><html5><css><css3>',
#    '<python><json><django><python-3.x><formularios>',
#    '<java><loops><operador-incremento>',
#    '<javascript><facebook><internet-explorer-11>',
#    '<javascript><jquery><ajax><datatables>',
#    '<java><jersey><swagger>',
#    '<raku>',
#    '<java><archivo-de-propiedades><i18n>',
#    '<jboss><seam><jboss-eap>',
#    '<java><spring><alfresco>',
#    '<javascript><c#><ajax><asp.net-mvc>',
#    '<javascript><jquery><thymeleaf>',
#    '<javascript><knockoutjs>',
#    '<git><git-push>',
#    '<oauth>',
#    '<shell><unix>',
#    '<java><hibernate><sqlite3><sqlite>',
#    '<shell>',
#    '<ios><objective-c>',
#    '<java><android><php><json>',
#    '<javascript><jquery><html5><asp.net-mvc-5>',
#    '<swift><string>',
#    '<c#><xml><soap><wcf>',
#    '<asp.net><windows><visual-studio><iis>',
#    '<python><bottle>',
#    '<javascript><array><object>',
#    '<javascript><angularjs>',
#    '<javascript><redondeo><amcharts>',
#    '<google-app-engine><objectify><google-datastore>',
#    '<javascript><angularjs><ajax>',
#    '<c++><array>',
#    '<json><visual-studio><asp.net-core>',
#    '<java><soap><struts>',
#    '<javascript><jasmine><momentjs>',
#    '<c#><xaml><uwp><binding><mvvm>',
#    '<python><django><djangorestframework>',
#    '<javascript><jquery><asp.net><vb.net>',
#    '<magento2>',
#    '<c++><java><rendimiento><optimización>',
#    '<mercurial><control-de-versiones>',
#    '<linux><vpn>',
#    '<bash><archivo>',
#    '<java>',
#    '<r><rodbc>',
#    '<git><github>',
#    '<windows><sublimetext><sublimetext3>',
#    '<java><constructor><clase-abstracta><poo>',
#    '<tsql>',
#    '<swift2><iphone>',
#    '<json><angularjs><nodejs>',
#    '<xml><codificación><utf-8>',
#    '<.net><regex><vb.net>',
#    '<javascript><html><css>',
#    '<ubuntu><nodejs><ec2><npm>',
#    '<android><json><http><gradle>',
#    '<plsql><sqldeveloper>',
#    '<sql-server><funciones><casting>',
#    '<html><css><bootstrap>',
#    '<c#><motor-de-juego><unity3d><2d>',
#    '<javascript><google-visualization>',
#    '<dns><iana>',
#    '<sql><sql-server><tsql>',
#    '<python><google-app-engine>',
#    '<php><laravel><laravel-5>',
#    '<javascript><nodejs><depuración>',
#    '<swift><swift2><xcode><parse.com>',
#    '<c++><casting>',
#    '<pharo><smalltalk>',
#    '<reactjs>',
#    '<javascript><ember.js>',
#    '<nodejs><npm>',
#    '<string><c><manejo-de-memoria>',
#    '<java><android><json>',
#    '<.net><entity-framework>',
#    '<c#><.net><asp.net><azure><azure-storage>',
#    '<pouchdb>',
#    '<php><mysql><mysqli>',
#    '<java><base-de-datos>',
#    '<javascript><html><google-maps><google-chrome>',
#    '<java><clase>',
#    '<oracle><postgresql>',
#    '<perl><matrices-asociativas><ordenamiento>',
#    '<android-studio><gradle>',
#    '<sql><sqlite3><sqlite>',
#    '<git><git-commit><github><git-push><git-fork>',
#    '<c#><asp.net-mvc-5>',
#    '<ios><xcode><swift><swift2>',
#    '<javascript><php><mysql>',
#    '<json><mongodb><nosql>',
#    '<c><manejo-de-memoria>',
#    '<plugin><wordpress>',
#    '<java><spring><spring-mvc><spring-security>',
#    '<unity3d>',
#    '<android><android-layout><unidades-de-medición>',
#    '<nodejs><post><permisos>',
#    '<java><windows><java-9>',
#    '<java><android><android-studio><gradle>',
#    '<perl><tipos><booleano>',
#    '<nodejs><http>',
#    '<html><css><google-chrome><internet-explorer>',
#    '<c#><xaml><windows-forms><wpf>',
#    '<jquery><ajax><asp.net-web-api><razor>',
#    '<java><php><json>',
#    '<java><string><comparaciones>',
#    '<c#><sql><asp.net-mvc><entity-framework>',
#    '<entity-framework><asp.net-mvc><linq>',
#    '<android><cordova>',
#    '<base-de-datos>',
#    '<json><asp.net-web-api>',
#    '<json>',
#    '<unity3d><webgl>',
#    '<apache>',
#    '<php><facebook>',
#    '<java><hilos><multitasking>',
#    '<linux><debian><ntfs>',
#    '<haskell><lista>',
#    '<docker>',
#    '<git><git-commit>',
#    '<poo><funciones><estándares>',
#    '<python><linux>',
#    '<php><formularios>',
#    '<jquery><bootstrap>',
#    '<html><xpath>',
#    '<android><android-auto>',
#    '<c#><wpf><xaml>',
#    '<ios><formularios><objective-c>',
#    '<bash><linux><shell><sed><awk>',
#    '<c++><string><tokens>',
#    '<oracle-10g><hql><jpa><seam>',
#    '<c#><visual-studio>',
#    '<java><android><xml>',
#    '<java><java-swing>',
#    '<typescript>',
#    '<javascript><comparaciones>',
#    '<asp.net><entity-framework><asp.net-mvc><linq>',
#    '<windows>',
#    '<linux><bash>',
#    '<python><linux><ubuntu><pygame>',
#    '<javascript><ajax><promesas>',
#    '<java><xstream>',
#    '<c#><linq><wcf>',
#    '<mysql><sql>',
#    '<java><conversión-de-tipos><tipos>',
#    '<java><java-ee><jsf><netbeans>',
#    '<javascript><jquery><asincronismo>',
#    '<api><nosql><couchdb>',
#    '<css3><sass><gulp><gulp-sass>',
#    '<php><optimización><poo>',
#    '<java><jsf><java-ee>',
#    '<subversion><svn>',
#    '<php><wordpress>',
#    '<excel><vba>',
#    '<html><facebook>',
#    '<javascript><sandbox><seguridad>',
#    '<python><django><api><djangorestframework>',
#    '<php><codeigniter><codeigniter-3>',
#    '<c#><sharepoint><sharepoint-online>',
#    '<php><laravel-5>',
#    '<javascript><constantes>',
#    '<javascript><pdf><google-apps-script>',
#    '<asp.net><visual-studio-2010>',
#    '<android><php><json><mysql>',
#    '<mysql><vagrant><puppet>',
#    '<html><css><html5><css3>',
#    '<python><django><python-3.x><django-models>',
#    '<python><django><html><css>',
#    '<perl><booleano><conversión-de-tipos>',
#    '<c#><asp.net-mvc-5><razor><asp.net-mvc>',
#    '<visual-studio><visual-studio-2015>',
#    '<python><linux><pip><ubuntu><python-2.7>',
#    '<javascript><google-apps-script><google-hoja-de-cálculo>',
#    '<html><.net>',
#    '<c#><asp.net-mvc-5><.net><entity-framework>',
#    '<c#><asp.net><visual-studio><iis>',
#    '<java><jpa>',
#    '<r><geolocalización>',
#    '<c++>',
#    '<ide><sublimetext><sublimetext3>',
#    '<python><python-3.x>',
#    '<django><django-models><django-admin><django-forms>',
#    '<ios><swift><xcode><iphone>',
#    '<javascript><jquery><eventos>',
#    '<c#><asp.net-web-api><automapper>',
#    '<javascript><datetime><momentjs><firebase>',
#    '<spring-mvc><spring-roo><gvnix>',
#    '<sql><oracle-11g><delphi>',
#    '<tcpip><tcp>',
#    '<nodejs>',
#    '<haskell><tipos><programación-funcional><scala>',
#    '<sql><oracle-11g>',
#    '<asp.net><bootstrap><vb.net>',
#    '<oracle><revisión-de-código>',
#    '<python><web2py>',
#    '<asp.net>',
#    '<jquery><sql><ajax><entity-framework><.net>',
#    '<java><alfresco>',
#    '<delphi>',
#    '<c++><constructor>',
#    '<javascript><ecmascript-2015>',
#    '<pdf><latex><lyx>',
#    '<css>',
#    '<sql><sql-server>',
#    '<python><macos>',
#    '<netbeans><maven>',
#    '<android><google-newsstand-producer><rss>',
#    '<php><codeigniter>',
#    '<angularjs><json><http><post>',
#    '<python><python-2.7><python-3.x>',
#    '<google-datastore><google-app-engine><objectify>',
#    '<android><sqlite>',
#    '<yii2>',
#    '<c#><asp.net-mvc-5><asp.net-mvc><azure><azure-redis>',
#    '<azure>',
#    '<html5><css><bootstrap><css3>',
#    '<mysql><windows><delphi>',
#    '<asp.net-mvc-5><asp.net-mvc><asp.net-web-api>',
#    '<javascript><html5>',
#    '<javascript><html>',
#    '<html><formularios>',
#    '<postgresql>',
#    '<android><diálogo>',
#    '<css><google-forms>',
#    '<java><try-catch>',
#    '<python><json><tweepy>',
#    '<javascript><c#><asp.net><asp.net-mvc>',
#    '<php><mysql><html5><bootstrap>',
#    '<java><android><optimización><android-sqlite>',
#    '<ionic>',
#    '<mongodb>',
#    '<java><java-ee><ide>',
#    '<javascript><jquery><html5><asp.net-mvc><bootstrap>',
#    '<visual-studio><nuget>',
#    '<vpn><windows>',
#    '<javascript><jquery><jquery-datepicker>',
#    '<python><yield>',
#    '<python><array><matplotlib><revisión-de-código><numpy>',
#    '<java><azul-zulu>',
#    '<java><xml>',
#    '<java><java-ee><jsf>',
#    '<ios><xcode><swift><ios8>',
#    '<ios><xcode><swift>',
#    '<latex>',
#    '<android><gradle>',
#    '<java><bigdecimal><redondeo><double>',
#    '<linux><c>',
#    '<sublimetext>',
#    '<swift><objective-c><iphone>',
#    '<nodejs><visual-studio-2015>',
#    '<java><jsf>',
#    '<angularjs><spring-mvc><spring-security>',
#    '<c#><windows-forms>',
#    '<python><python-2.7><lista>',
#    '<php><timestamp>',
#    '<java><android><admob>',
#    '<python><python-2.7>',
#    '<ruby-on-rails><ruby><vistas>',
#    '<mongodb><nosql>',
#    '<oracle><formularios><oracle-10g>',
#    '<jquery><asp.net><asp.net-mvc-5><ajax>',
#    '<javascript><java><servlets><socket>',
#    '<mysql>',
#    '<api><ruby><http><post>',
#    '<c>',
#    '<swift2><spritekit>',
#    '<java><poo>',
#    '<sql>',
#    '<linux><unix>',
#    '<php><sqlite3>',
#    '<meteor><cuenta-usuario>',
#    '<javascript><jquery><datatables>',
#    '<git>',
#    '<java><netbeans>',
#    '<c#><asp.net><aplicación-web>',
#    '<javascript><html5><indexeddb>',
#    '<validación><formularios><html5>',
#    '<git><git-commit><git-push><control-de-versiones>',
#    '<javascript><meteor><iron-router>',
#    '<python><python-2.7><clase><método>',
#    '<java><string><java-8><java-stream>',
#    '<c><arduino>',
#    '<swift>',
#    '<wordpress><tinymce>',
#    '<ruby-on-rails>',
#    '<eclipse><ftp>',
#    '<jvm><java>',
#    '<array><perl>',
#    '<sql><oracle><oracle-10g>',
#    '<javascript><jquery><html><html5>',
#    '<php><mysql><mysqli><seguridad>',
#    '<html5><sql-server><bootstrap><vb.net>',
#    '<php><sql-server><laravel-5>',
#    '<doctrine><symfony2>',
#    '<java><android><bitmap>',
#    '<c#><asp.net><asp.net-web-api>',
#    '<fish>',
#    '<java><eclipse><depuración><jboss>',
#    '<sql><oracle>',
#    '<asp.net><asp.net-mvc-5><asp.net-mvc><razor>',
#    '<python><xml>',
#    '<jquery><vb.net>',
#    '<vb.net><asp.net-mvc><entity-framework><linq>',
#    '<javascript><html><vistas><backbone>',
#    '<c#><entity-framework><entity-framework-6>',
#    '<jsf><primefaces>',
#    '<php><sql-server>',
#    '<windows-installer>',
#    '<javascript><.net><signalr><real-time>',
#    '<asp.net-mvc-5>',
#    '<javascript><revisión-de-código>',
#    '<java><java-util-scanner>',
#    '<arduino>',
#    '<php><phpmyadmin><symfony2>',
#    '<php><laravel>',
#    '<javascript>',
#    '<sql><oracle-11g><sqlfiddle>',
#    '<java><eclipse><maven>',
#    '<git><github><git-push><git-fork>',
#    '<javascript><ionic><parse.com>',
#    '<c#><linux><apache><asp.net-core>',
#    '<php>',
#    '<javascript><html><xhtml>',
#    '<ruby-on-rails><rspec>',
#    '<html><jquery-datepicker>',
#    '<json><swift2>',
#    '<doctrine><doctrine2>',
#    '<mysql><python><base-de-datos>',
#    '<php><angularjs><mysqli>',
#    '<css><internet-explorer><internet-explorer-9>',
#    '<php><email>',
#    '<javascript><jsp><cq5><aem>',
#    '<swift><admob>',
#    '<javascript><jquery><asp.net-mvc-5>',
#    '<mysql><base-de-datos>',
#    '<asp.net-mvc-5><asp.net-mvc><linq>',
#    '<django><sql><postgresql>',
#    '<c++><makefile>',
#    '<java><json><gson>',
#    '<html><html5>',
#    '<mysql><datetime><timestamp>',
#    '<javascript><fullcalendar>',
#    '<java><excel><apache-poi>',
#    '<entity-framework><wcf>',
#    '<java><spring><spring-mvc>',
#    '<json><wcf>',
#    '<angularjs><pdf>',
#    '<javascript><jquery><asp.net>',
#    '<css><bootstrap><laravel-5><pdf>',
#    '<angularjs>',
#    '<javascript><php><regex>',
#    '<c++><qt>',
#    '<python><python-3.x><tkinter>',
#    '<bash><zsh>',
#    '<google-maps><angularjs><jasmine><karma-jasmine>',
#    '<typescript><aurelia.io><select2>',
#    '<ios><xcode><objective-c>',
#    '<java><string><regex>',
#    '<python><excepciones>',
#    '<php><yii2><i18n>',
#    '<java><gradle><intellij-idea><javadoc>',
#    '<git><mercurial>',
#    '<ios>',
#    '<string><delphi><split>',
#    '<c#><jquery><json><asp.net><ajax>',
#    '<python><matplotlib><pyqt5><embebido>',
#    '<git><control-de-versiones>',
#    '<javascript><parse.com>',
#    '<java><localización>',
#    '<python><django>',
#    '<ios><objective-c><uiwebview><ios8>',
#    '<c#><.net><revisión-de-código>',
#    '<android><arduino><socket><delphi><tcpip>',
#    '<javascript><regex>',
#    '<javascript><jquery><php><ajax>',
#    '<android-studio>',
#    '<python><xml><revisión-de-código>',
#    '<genexus>',
#    '<operador>',
#    '<javascript><java><string><regex><lenguaje-agnóstico>',
#    '<spring><hibernate><jpa><spring-mvc>',
#    '<java><netbeans><plugin>',
#    '<java><android><variables>',
#    '<google-hoja-de-cálculo><formulas><formato-condicional>',
#    '<python><tkinter>']}]

# %% [markdown]
# ### `$out`
#
# Este comando permite volcar el resultado de un pipeline de agregación en una nueva colección en la base de datos.

# %%
respuestas: CommandCursor[dict[str, Any]] = db.posts.aggregate( [
        { '$match': { 'Score' : {'$gte': 40}}},
        { '$lookup': {
            'from': "users",
            'localField': "OwnerUserId",
            'foreignField': "Id",
            'as': "owner"
          }
        },
        { '$unwind': '$owner'},
        { '$project' : {
             'username': '$owner.DisplayName'
          }
        },
        {'$out': "stackoverflow_users"}
      ])

# %% [markdown]
# Un documento de ejemplo de la colección generada `stackoverflow_users`:

# %%
pp(db.stackoverflow_users.find_one())
# Out:
# {'_id': ObjectId('67c9e68502ff02b3f27e1e22'), 'username': 'Konamiman'}

# %%
db.stackoverflow_users.count_documents({})
# Out:
# 122

# %% [markdown]
# ## Ejemplos básicos de agregación

# %% [markdown]
# ### Ejemplo 1: Asociación usuarios con Tags
#
# Con Agregación, vamos a construir una colección que asocia un usuario con los tags que ha usado en todas sus preguntas.
#
# *Por cuestiones de rendimiento vamos a limitar la agregación a 500 elementos.*

# %%
user_tags: CommandCursor[dict[str, Any]] = db.posts.aggregate([
        { "$match" : {"PostTypeId": 1}},

        {"$limit": 500},

        { '$lookup': {
            'from': "users",
            'localField': "OwnerUserId",
            'foreignField': "Id",
            'as': "owner"
          }
        },

        {'$project':{
            'Tags': True,
            'userid' : {'$arrayElemAt' : ['$owner.Id', 0]},
        }},

        {'$group':{
            '_id':'$userid',
            'AllTags': { '$addToSet': "$Tags" }
        }}
]
)

user_tags_lst = list(user_tags)
user_tags_lst
# Out:
# [{'_id': 1005,
#   'AllTags': ['<python><djangorestframework><django-models>',
#    '<python><django><python-3.x><django-models>',
#    '<python><django><django-models><users-roles>',
#    '<django><django-models>',
#    '<python><django>']},
#  {'_id': 2027,
#   'AllTags': ['<javascript><jquery><jquery-datepicker>',
#    '<c#><conversión-de-tipos><tipos>',
#    '<git>',
#    '<java><conversión-de-tipos><tipos>']},
#  {'_id': 250, 'AllTags': ['<javascript><jquery><html><html5>']},
#  {'_id': 1365, 'AllTags': ['<yii>']},
#  {'_id': 1958, 'AllTags': ['<java><android>', '<java><android><json>']},
#  {'_id': 870, 'AllTags': ['<hilos>', '<python><python-2.7>']},
#  {'_id': 1788, 'AllTags': ['<javascript><html>']},
#  {'_id': 292,
#   'AllTags': ['<python><python-3.x>',
#    '<meteor><cuenta-usuario>',
#    '<ide><sublimetext><sublimetext3>']},
#  {'_id': 872, 'AllTags': ['<javascript>']},
#  {'_id': 555, 'AllTags': ['<git><git-merge>', '<git>', '<git><git-push>']},
#  {'_id': 1390, 'AllTags': ['<oracle><formularios><oracle-10g>']},
#  {'_id': 1941, 'AllTags': ['<c#><ofuscación>']},
#  {'_id': 1505,
#   'AllTags': ['<javascript><angularjs>', '<javascript><jquery><angularjs>']},
#  {'_id': 1037, 'AllTags': ['<javascript><html><vistas><backbone>']},
#  {'_id': 2509, 'AllTags': ['<javascript><angularjs>']},
#  {'_id': 2327, 'AllTags': ['<nodejs><post><permisos>']},
#  {'_id': 90, 'AllTags': ['<mysql><sql>']},
#  {'_id': 1913, 'AllTags': ['<json><swift2>']},
#  {'_id': 1870,
#   'AllTags': ['<java><android>', '<java><android><android-layout>']},
#  {'_id': 1007, 'AllTags': ['<mysql><phpmyadmin>']},
#  {'_id': 400,
#   'AllTags': ['<javascript><jquery><asincronismo>',
#    '<javascript><java><jquery>',
#    '<java><jpa>',
#    '<java><alfresco>',
#    '<java><thymeleaf>',
#    '<javascript><jquery><thymeleaf>']},
#  {'_id': 24,
#   'AllTags': ['<c++><string><tokens>',
#    '<c++><string>',
#    '<c++><c++11>',
#    '<c++><c>',
#    '<c++><casting>',
#    '<c++>']},
#  {'_id': 1881, 'AllTags': ['<swift>']},
#  {'_id': 535, 'AllTags': ['<python><django><ordenamiento>']},
#  {'_id': 2059, 'AllTags': ['<python><xml>']},
#  {'_id': 2034, 'AllTags': ['<java><android>']},
#  {'_id': 660, 'AllTags': ['<mysql><sql>']},
#  {'_id': 399,
#   'AllTags': ['<mysql><vagrant><puppet>', '<git>', '<javascript>']},
#  {'_id': 1776, 'AllTags': ['<xml>']},
#  {'_id': 160, 'AllTags': ['<ios><formularios><objective-c>']},
#  {'_id': 1947, 'AllTags': ['<javascript><jquery><api><google-drive>']},
#  {'_id': 901, 'AllTags': ['<django><api><djangorestframework><permisos>']},
#  {'_id': 25,
#   'AllTags': ['<licencias><código-abierto>',
#    '<javascript>',
#    '<c++><c++11>',
#    '<c++><array>',
#    '<git>',
#    '<c#>']},
#  {'_id': 325, 'AllTags': ['<soap><soapui><wcf><servicio>']},
#  {'_id': 1098, 'AllTags': ['<abap>']},
#  {'_id': 2392, 'AllTags': ['<php><sql>', '<php>']},
#  {'_id': 2247, 'AllTags': ['<c#><jquery><asp.net-mvc-5><asp.net>']},
#  {'_id': 2346, 'AllTags': ['<javascript>']},
#  {'_id': 2152, 'AllTags': ['<python><archivo>', '<python><python-2.7>']},
#  {'_id': 23,
#   'AllTags': ['<c#>',
#    '<javascript><angularjs><ajax>',
#    '<javascript><angularjs>',
#    '<javascript><jasmine><momentjs>',
#    '<.net><asp.net-web-api><asp.net>',
#    '<google-maps><angularjs><jasmine><karma-jasmine>']},
#  {'_id': 729,
#   'AllTags': ['<javascript><google-maps>',
#    '<php><yii2>',
#    '<javascript><ecmascript-2015>',
#    '<magento2>',
#    '<html><xpath>',
#    '<php>',
#    '<bash><linux>',
#    '<javascript><array>',
#    '<javascript><php><regex>',
#    '<javascript><html>',
#    '<php><joomla3>',
#    '<javascript><poo>',
#    '<javascript><html><css>',
#    '<javascript><jquery>',
#    '<git>',
#    '<javascript>']},
#  {'_id': 1092, 'AllTags': ['<c#><visual-studio>']},
#  {'_id': 2540, 'AllTags': ['<python><python-2.7><python-3.x>']},
#  {'_id': 2019, 'AllTags': ['<java><postgresql>']},
#  {'_id': 2208, 'AllTags': ['<seo>']},
#  {'_id': 1389, 'AllTags': ['<html5><css3><bootstrap><wordpress>']},
#  {'_id': 517,
#   'AllTags': ['<java><bigdecimal><redondeo><double>',
#    '<javascript><jquery><html>',
#    '<java><loops><operador-incremento>',
#    '<java><string><comparaciones>',
#    '<algoritmos><lenguaje-agnóstico><loops><condiciones>',
#    '<javascript><comparaciones>',
#    '<java><string><regex>',
#    '<java><string><java-8><java-stream>',
#    '<java>',
#    '<javascript><array>']},
#  {'_id': 745, 'AllTags': ['<.net><regex><vb.net>']},
#  {'_id': 65,
#   'AllTags': ['<javascript><google-apps-script><google-hoja-de-cálculo><google-forms><google-documentos>',
#    '<javascript><google-apps-script><google-hoja-de-cálculo>',
#    '<css><google-forms>',
#    '<javascript><bookmarklet><gmail>',
#    '<javascript><google-apps-script><google-hoja-de-cálculo><google-forms>']},
#  {'_id': 1173, 'AllTags': ['<javascript><html5><indexeddb>']},
#  {'_id': 728, 'AllTags': ['<genexus>']},
#  {'_id': 307, 'AllTags': ['<dns><iana>']},
#  {'_id': 37, 'AllTags': ['<ios><xcode>', '<lista><elixir>']},
#  {'_id': 35,
#   'AllTags': ['<asp.net><asp.net-mvc><librería><bower>',
#    '<javascript><kendoui><knockoutjs>',
#    '<javascript><knockoutjs>']},
#  {'_id': 371, 'AllTags': ['<django><sql><postgresql>']},
#  {'_id': 636,
#   'AllTags': ['<javascript><underscorejs>',
#    '<javascript><datetime><momentjs><firebase>',
#    '<javascript><momentjs><underscorejs>']},
#  {'_id': 1914, 'AllTags': ['<php><sql-server>', '<java><android>', '<git>']},
#  {'_id': 783, 'AllTags': ['<python><pip><pillow>']},
#  {'_id': 403, 'AllTags': ['<ios><objective-c>']},
#  {'_id': 299, 'AllTags': ['<git><git-commit>']},
#  {'_id': 264, 'AllTags': ['<sql><oracle>', '<jvm><java>']},
#  {'_id': 965,
#   'AllTags': ['<javascript><clausuras>',
#    '<ios><objective-c><uiwebview><ios8>']},
#  {'_id': 2235, 'AllTags': ['<python><string><ordenamiento>']},
#  {'_id': 629,
#   'AllTags': ['<typescript><aurelia.io><select2>',
#    '<javascript><jquery><typescript>',
#    '<c#><jquery><ajax><asp.net-mvc-5><asp.net-mvc>']},
#  {'_id': 2367, 'AllTags': ['<javascript><jquery><html5>']},
#  {'_id': 167, 'AllTags': ['<java><java-ee><ide>']},
#  {'_id': 77, 'AllTags': ['<sql><sql-server>']},
#  {'_id': 1798, 'AllTags': ['<git>']},
#  {'_id': 211, 'AllTags': ['<json><visual-studio><asp.net-core>']},
#  {'_id': 1547, 'AllTags': ['<javascript>']},
#  {'_id': 463, 'AllTags': ['<c++><c++11>', '<c#><.net>', '<c++><qt>', '<c++>']},
#  {'_id': 1943,
#   'AllTags': ['<java>',
#    '<tcpip><tcp>',
#    '<java><android>',
#    '<git><git-commit>',
#    '<java><hilos><multitasking>']},
#  {'_id': 238, 'AllTags': ['<jquery><html><youtube>']},
#  {'_id': 2036, 'AllTags': ['<c#><asp.net-mvc-5>']},
#  {'_id': 389,
#   'AllTags': ['<python><punteros>', '<python><imagen>', '<bash><verilog>']},
#  {'_id': 2379, 'AllTags': ['<java><android><linux><windows>']},
#  {'_id': 2352, 'AllTags': ['<javascript>']},
#  {'_id': 1592, 'AllTags': ['<java><android><avd>']},
#  {'_id': 2531, 'AllTags': ['<vb.net>']},
#  {'_id': 2004,
#   'AllTags': ['<javascript><html><google-maps><google-chrome>',
#    '<python><matemáticas>',
#    '<oauth>',
#    '<c#><.net>',
#    '<spring><hibernate><jpa><spring-mvc>',
#    '<javascript><json><string>',
#    '<javascript>']},
#  {'_id': 749, 'AllTags': ['<excel><vba>']},
#  {'_id': 239, 'AllTags': ['<ios><jquery><cordova>']},
#  {'_id': 305,
#   'AllTags': ['<android><android-layout><unidades-de-medición>',
#    '<android><android-softkeyboard>']},
#  {'_id': 1076, 'AllTags': ['<select2><yii><yiibooster><cache>']},
#  {'_id': 2256,
#   'AllTags': ['<javascript><angularjs>',
#    '<json><asp.net-web-api>',
#    '<sql><sql-server><tsql>']},
#  {'_id': 1948, 'AllTags': ['<jsf><primefaces>']},
#  {'_id': 1997, 'AllTags': ['<c++>']},
#  {'_id': 22,
#   'AllTags': ['<array><perl>',
#    '<javascript><jquery><eventos>',
#    '<pouchdb>',
#    '<go><tipos>',
#    '<perl><booleano><conversión-de-tipos>',
#    '<javascript><nodejs>',
#    '<go>',
#    '<git>',
#    '<javascript><sandbox><seguridad>']},
#  {'_id': 21,
#   'AllTags': ['<delphi>',
#    '<mysql><datetime><timestamp>',
#    '<mysql><sql><join>',
#    '<sql><oracle><oracle-10g>',
#    '<javascript><jquery>',
#    '<android><arduino><socket><delphi><tcpip>']},
#  {'_id': 1575, 'AllTags': ['<python>']},
#  {'_id': 252, 'AllTags': ['<clojure>']},
#  {'_id': 345, 'AllTags': ['<sequelize.js><pruebas-unitarias>']},
#  {'_id': 1543, 'AllTags': ['<r><rodbc>']},
#  {'_id': 2186, 'AllTags': ['<api><nosql><couchdb>']},
#  {'_id': 2399, 'AllTags': ['<java><io>']},
#  {'_id': 2234, 'AllTags': ['<python>']},
#  {'_id': 301,
#   'AllTags': ['<c++><constructor>',
#    '<java><localización>',
#    '<java>',
#    '<java><clase>',
#    '<java><paso-por-valor><paso-por-referencia>',
#    '<c++><makefile>',
#    '<c++>',
#    '<c++><java><rendimiento><optimización>',
#    '<java><c++><punteros>']},
#  {'_id': 261, 'AllTags': ['<java><try-catch>']},
#  {'_id': 100,
#   'AllTags': ['<mysql><python><base-de-datos>',
#    '<python><excepciones>',
#    '<python><archivo>',
#    '<python><python-2.7><clase><método>',
#    '<android><cordova><ionic>',
#    '<javascript><array>',
#    '<bash><linux>',
#    '<python><linux><pip><ubuntu><python-2.7>',
#    '<javascript><jquery><asincronismo>',
#    '<python><python-2.7><funciones>',
#    '<haskell>',
#    '<python>',
#    '<python><django><python-3.x><celery>',
#    '<mercurial><control-de-versiones>',
#    '<validación><formularios><html5>',
#    '<nginx><logrotate><configuración>',
#    '<python><django>',
#    '<python><python-3.x><pdf><reportlab>',
#    '<python><python-3.x><datetime>',
#    '<haskell><lista>',
#    '<python><python-2.7>']},
#  {'_id': 1399,
#   'AllTags': ['<jquery><vb.net>', '<asp.net><visual-studio-2010>']},
#  {'_id': 846, 'AllTags': ['<java><android><bitmap>']},
#  {'_id': 1270, 'AllTags': ['<python><django><python-3.x><django-models>']},
#  {'_id': 2335, 'AllTags': ['<genexus>']},
#  {'_id': 2387, 'AllTags': ['<eclipse><ftp>']},
#  {'_id': 366, 'AllTags': ['<javascript>']},
#  {'_id': 2288, 'AllTags': ['<java><spring><spring-mvc><spring-security>']},
#  {'_id': 908, 'AllTags': ['<python><web2py>']},
#  {'_id': 1188, 'AllTags': ['<c#><asp.net-web-api><automapper>']},
#  {'_id': 2304, 'AllTags': ['<php><codeigniter><codeigniter-3>']},
#  {'_id': 533, 'AllTags': ['<plugin><wordpress>']},
#  {'_id': 816, 'AllTags': ['<python><django>']},
#  {'_id': 2366,
#   'AllTags': ['<javascript><jquery><html>',
#    '<javascript><jquery><asp.net-mvc-5>']},
#  {'_id': 217,
#   'AllTags': ['<poo><funciones><estándares>', '<string><php><str-replace>']},
#  {'_id': 271,
#   'AllTags': ['<latex>',
#    '<linux><debian><ntfs>',
#    '<python><macos>',
#    '<html><html5>',
#    '<r><ggplot2>']},
#  {'_id': 701, 'AllTags': ['<spring><spring-roo><gvnix>']},
#  {'_id': 1972, 'AllTags': ['<java><hibernate><sqlite3><sqlite>']},
#  {'_id': 78, 'AllTags': ['<c#><sharepoint><sharepoint-online>']},
#  {'_id': 676, 'AllTags': ['<genexus>']},
#  {'_id': 2113, 'AllTags': ['<javascript>']},
#  {'_id': 731, 'AllTags': ['<javascript><jquery><json>']},
#  {'_id': 722, 'AllTags': ['<genexus><devices>']},
#  {'_id': 1303, 'AllTags': ['<linux><vpn>']},
#  {'_id': 2238,
#   'AllTags': ['<c#><xaml><windows-forms><wpf>',
#    '<c#><windows-forms>',
#    '<javascript><jquery>']},
#  {'_id': 1055, 'AllTags': ['<php><yii2><i18n>']},
#  {'_id': 2338, 'AllTags': ['<python><python-2.7>']},
#  {'_id': 27, 'AllTags': ['<javascript><android><reactjs><react-native>']},
#  {'_id': 120,
#   'AllTags': ['<javascript><html><xhtml>', '<sql><ms-access-2010>']},
#  {'_id': 342,
#   'AllTags': ['<java><netbeans><plugin>',
#    '<java>',
#    '<javascript>',
#    '<java><dukescript><admob>',
#    '<netbeans>',
#    '<unity3d>',
#    '<netbeans><maven>',
#    '<javascript><jquery><json>',
#    '<javascript><html><json><knockoutjs>',
#    '<git><git-commit><github><git-push><git-fork>',
#    '<java><dukescript>',
#    '<java><archivo-de-propiedades><i18n>',
#    '<css>',
#    '<jboss><seam><jboss-eap>',
#    '<oracle-10g><hql><jpa><seam>',
#    '<oracle><oracle-11g><sqlfiddle>',
#    '<oracle><sqlfiddle>',
#    '<html>',
#    '<css><jsfiddle><scss>',
#    '<java><sql><oracle><jdbc>',
#    '<css><html5><css3><3d><importación>',
#    '<java><eclipse><depuración><jboss>',
#    '<c#><unity3d>',
#    '<oracle><oracle-11g>']},
#  {'_id': 1996, 'AllTags': ['<angularjs>']},
#  {'_id': 1184,
#   'AllTags': ['<mysql><windows><delphi>',
#    '<archivo><windows><consola><proceso>',
#    '<sql><oracle><oracle-11g>',
#    '<google-hoja-de-cálculo><formulas><formato-condicional>',
#    '<sql><oracle>',
#    '<sql><oracle-11g><sqlfiddle>']},
#  {'_id': 2230, 'AllTags': ['<xaml><uwp>', '<c#><uwp>']},
#  {'_id': 73, 'AllTags': ['<php><ajax><laravel><laravel-5>']},
#  {'_id': 813, 'AllTags': ['<vpn><windows>']},
#  {'_id': 132,
#   'AllTags': ['<javascript><array><object>',
#    '<javascript><jquery><dom>',
#    '<php><timestamp>']},
#  {'_id': 1859, 'AllTags': ['<tsql>']},
#  {'_id': 725, 'AllTags': ['<genexus>']},
#  {'_id': 75, 'AllTags': ['<reactjs>', '<git><control-de-versiones>']},
#  {'_id': 608,
#   'AllTags': ['<mongodb>',
#    '<java><android><navigationview>',
#    '<java><jersey><swagger>',
#    '<java><android>',
#    '<java><hibernate>']},
#  {'_id': 1809, 'AllTags': ['<java><apache-poi>', '<java><excel><apache-poi>']},
#  {'_id': 416, 'AllTags': ['<matemáticas><coma-flotante><lenguaje-agnóstico>']},
#  {'_id': 1583, 'AllTags': ['<javascript><facebook><internet-explorer-11>']},
#  {'_id': 1555, 'AllTags': ['<java><oracle><base64>']},
#  {'_id': 1839,
#   'AllTags': ['<javascript><json><angularjs>',
#    '<javascript><jquery>',
#    '<javascript>',
#    '<javascript><jquery><json>',
#    '<javascript><json><xml>',
#    '<visual-studio><nuget>']},
#  {'_id': 2262, 'AllTags': ['<php><sql><mysql><phpmyadmin><mysqli>']},
#  {'_id': 302,
#   'AllTags': ['<pharo><smalltalk>',
#    '<python><python-3.x>',
#    '<archivo><fish><exists>',
#    '<programación-funcional><haskell><estructuras-de-datos>']},
#  {'_id': 417, 'AllTags': ['<java><soap><struts>', '<git>']},
#  {'_id': 1360, 'AllTags': ['<javascript><pdf><google-apps-script>']},
#  {'_id': 2013,
#   'AllTags': ['<linux><c>',
#    '<git><github>',
#    '<git><github><git-push><git-fork>',
#    '<linux><grep>']},
#  {'_id': 127,
#   'AllTags': ['<xml><codificación><utf-8>',
#    '<php><array>',
#    '<javascript><validación><email><regex>']},
#  {'_id': None,
#   'AllTags': ['<java><spring><spring-mvc>',
#    '<javascript><angularjs>',
#    '<paso-por-valor><paso-por-referencia><lenguaje-agnóstico>',
#    '<java><java-ee><servlets>',
#    '<.net><clickonce><deployment>']},
#  {'_id': 632, 'AllTags': ['<archivo><linux><rsync>', '<raku>']},
#  {'_id': 1482, 'AllTags': ['<c#><.net><asp.net><azure><azure-storage>']},
#  {'_id': 2325, 'AllTags': ['<c#>']},
#  {'_id': 2394, 'AllTags': ['<jquery><django><django-models><ajax>']},
#  {'_id': 2488, 'AllTags': ['<c#><.net>']},
#  {'_id': 717, 'AllTags': ['<directorioactivo><office365><smartcard><adfs>']},
#  {'_id': 2539, 'AllTags': ['<android><php><json><mysql>']},
#  {'_id': 298,
#   'AllTags': ['<c#><.net><entity-framework><asp.net-core><model-view-controller>']},
#  {'_id': 74, 'AllTags': ['<python><numpy><array>', '<python><yield>']},
#  {'_id': 1725, 'AllTags': ['<mongodb><nosql>']},
#  {'_id': 1623, 'AllTags': ['<wolfram-mathematica>']},
#  {'_id': 2257,
#   'AllTags': ['<c#><motor-de-juego><unity3d><2d>', '<c#><unity3d>']},
#  {'_id': 2349, 'AllTags': ['<ruby-on-rails>']},
#  {'_id': 288,
#   'AllTags': ['<perl><tipos><booleano>',
#    '<perl><matrices-asociativas><ordenamiento>']},
#  {'_id': 72, 'AllTags': ['<c#>']},
#  {'_id': 2236, 'AllTags': ['<c++><visual-studio-2010>']},
#  {'_id': 547,
#   'AllTags': ['<javascript><.net><signalr><real-time>',
#    '<javascript><jquery><datatables>']},
#  {'_id': 2453, 'AllTags': ['<java><primefaces>']},
#  {'_id': 1905, 'AllTags': ['<ssms>']},
#  {'_id': 1203, 'AllTags': ['<sql-server><asp.net-mvc-5>']},
#  {'_id': 2163, 'AllTags': ['<java><android><admob>']},
#  {'_id': 260, 'AllTags': ['<html><css>', '<java>', '<git><git-commit>']},
#  {'_id': 1168,
#   'AllTags': ['<vb.net><windows-forms>', '<c#><asp.net-mvc-5><razor>']},
#  {'_id': 1577, 'AllTags': ['<c#><windows-forms>']},
#  {'_id': 2041,
#   'AllTags': ['<javascript><android><ajax><cordova><jquery-mobile>']},
#  {'_id': 1687, 'AllTags': ['<java><firebird>']},
#  {'_id': 2136, 'AllTags': ['<angularjs><json><http><post>']},
#  {'_id': 2137, 'AllTags': ['<swift2>']},
#  {'_id': 2133, 'AllTags': ['<mongodb><nosql>']},
#  {'_id': 2087, 'AllTags': ['<php><laravel>']},
#  {'_id': 1545, 'AllTags': ['<php><laravel-5>']},
#  {'_id': 149, 'AllTags': ['<string><c#>', '<javascript><nodejs>']},
#  {'_id': 631,
#   'AllTags': ['<ubuntu><nodejs><ec2><npm>', '<ruby-on-rails><rspec>']},
#  {'_id': 360,
#   'AllTags': ['<php><doctrine><doctrine2>', '<laravel><laravel-5>']},
#  {'_id': 1499,
#   'AllTags': ['<ios><objective-c>',
#    '<ios><xcode><objective-c>',
#    '<ios><swift2><xcode>']},
#  {'_id': 348, 'AllTags': ['<azure>']},
#  {'_id': 801, 'AllTags': ['<python><matplotlib><pyqt5><embebido>']},
#  {'_id': 659, 'AllTags': ['<php><poo>']},
#  {'_id': 2282, 'AllTags': ['<swift><swift2>']},
#  {'_id': 225,
#   'AllTags': ['<html5><css><bootstrap><css3>',
#    '<c#><asp.net-mvc-5><razor><asp.net-mvc>',
#    '<c#><asp.net-mvc-5><razor>']},
#  {'_id': 1746, 'AllTags': ['<php><mysql><mysqli>']},
#  {'_id': 143, 'AllTags': ['<java><json><gson>']},
#  {'_id': 218, 'AllTags': ['<python><variables>']},
#  {'_id': 92, 'AllTags': ['<wpf><xaml>', '<c#><wpf><xaml>', '<c#><reflexión>']},
#  {'_id': 1840, 'AllTags': ['<c#><windows-forms>']},
#  {'_id': 2156, 'AllTags': ['<javascript><jquery>']},
#  {'_id': 1784, 'AllTags': ['<ios><swift2>']},
#  {'_id': 531,
#   'AllTags': ['<c#><windows-forms>', '<c#><sql-server><windows-forms>']},
#  {'_id': 353, 'AllTags': ['<python><conda>', '<python><django>', '<conda>']},
#  {'_id': 2293, 'AllTags': ['<java><base-de-datos><archivo-de-propiedades>']},
#  {'_id': 2357, 'AllTags': ['<java><jsf><java-ee>']},
#  {'_id': 1527,
#   'AllTags': ['<ios><xcode><swift><swift2>',
#    '<ios><swift><xcode><iphone>',
#    '<ios><swift><swift2>',
#    '<ios><xcode><swift>',
#    '<ios><xcode><swift><ios8>']},
#  {'_id': 1965, 'AllTags': ['<python><python-2.7><lista>', '<bash><shell>']},
#  {'_id': 29,
#   'AllTags': ['<api><ruby><http><post>', '<ruby-on-rails><ruby><vistas>']},
#  {'_id': 1274, 'AllTags': ['<python><django><python-2.7>']},
#  {'_id': 187,
#   'AllTags': ['<javascript><nodejs><depuración>',
#    '<c><manejo-de-memoria>',
#    '<mysql><java><spring><hibernate>',
#    '<json><mongodb><nosql>',
#    '<java><constructor><clase-abstracta><poo>',
#    '<c><hilos>']},
#  {'_id': 95, 'AllTags': ['<android><google-newsstand-producer><rss>']},
#  {'_id': 1827, 'AllTags': ['<html5><bootstrap>']},
#  {'_id': 20, 'AllTags': ['<typescript>']},
#  {'_id': 233, 'AllTags': ['<ios>', '<ios><xcode>']},
#  {'_id': 1507, 'AllTags': ['<php><optimización><poo>']},
#  {'_id': 2222, 'AllTags': ['<bash><shell>']},
#  {'_id': 921, 'AllTags': ['<.net><entity-framework>']},
#  {'_id': 2295, 'AllTags': ['<html><html5><css><css3>']},
#  {'_id': 546, 'AllTags': ['<android><android-auto>']},
#  {'_id': 2224, 'AllTags': ['<javascript><jquery>', '<html><formularios>']},
#  {'_id': 430, 'AllTags': ['<javascript><ember.js>', '<javascript>']},
#  {'_id': 1119, 'AllTags': ['<windows>']},
#  {'_id': 2172, 'AllTags': ['<android-studio><ubuntu><java>']},
#  {'_id': 1513, 'AllTags': ['<swift2>', '<ios><swift><swift2>']},
#  {'_id': 206,
#   'AllTags': ['<java><android><optimización><android-sqlite>',
#    '<java><android><android-intent><android-asynctask>']},
#  {'_id': 83,
#   'AllTags': ['<bash><zsh>',
#    '<archivo><unix><grep><ascii>',
#    '<bash><archivo>',
#    '<git><git-commit>',
#    '<bash><linux><shell><sed><awk>']},
#  {'_id': 270, 'AllTags': ['<ios><objective-c><swift>']},
#  {'_id': 398,
#   'AllTags': ['<git><visual-studio><nodejs><azure>',
#    '<visual-studio><azure><visual-studio-2015>']},
#  {'_id': 1407, 'AllTags': ['<javascript><angularjs>']}]

# %% [markdown]
# ### Ejemplo 2: Asociación Tags con usuarios
#
# Ahora, dado un ID de tag, qué usuarios han hecho preguntas de ese tag.
#
# *De nuevo limitamos la búsqueda a 500 documentos*

# %%
tags_users: CommandCursor[dict[str, Any]] = db.posts.aggregate( [
        { "$match" : {"PostTypeId": 1}},

        {"$limit": 500},

        { '$lookup': {
            'from': "users",
            'localField': "OwnerUserId",
            'foreignField': "Id",
            'as': "owner"
          }
        },

        {'$project':{
            'Tags': True,
            'userid' : {'$arrayElemAt' : ['$owner.Id', 0]},
        }},

        {'$group':{
            '_id':'$Tags',
            'AllUsers': { '$addToSet': "$userid" }
        }}
    ])

tags_users_lst = list(tags_users)
tags_users_lst
# Out:
# [{'_id': '<xml><codificación><utf-8>', 'AllUsers': [127]},
#  {'_id': '<mongodb>', 'AllUsers': [608]},
#  {'_id': '<jboss><seam><jboss-eap>', 'AllUsers': [342]},
#  {'_id': '<javascript><html5><indexeddb>', 'AllUsers': [1173]},
#  {'_id': '<string><php><str-replace>', 'AllUsers': [217]},
#  {'_id': '<javascript><google-maps>', 'AllUsers': [729]},
#  {'_id': '<lista><elixir>', 'AllUsers': [37]},
#  {'_id': '<ios><swift><swift2>', 'AllUsers': [1513, 1527]},
#  {'_id': '<tcpip><tcp>', 'AllUsers': [1943]},
#  {'_id': '<javascript><datetime><momentjs><firebase>', 'AllUsers': [636]},
#  {'_id': '<poo><funciones><estándares>', 'AllUsers': [217]},
#  {'_id': '<git><github><git-push><git-fork>', 'AllUsers': [2013]},
#  {'_id': '<c#><jquery><asp.net-mvc-5><asp.net>', 'AllUsers': [2247]},
#  {'_id': '<php><codeigniter><codeigniter-3>', 'AllUsers': [2304]},
#  {'_id': '<javascript><google-apps-script><google-hoja-de-cálculo>',
#   'AllUsers': [65]},
#  {'_id': '<java><dukescript><admob>', 'AllUsers': [342]},
#  {'_id': '<java><java-ee><servlets>', 'AllUsers': []},
#  {'_id': '<php><optimización><poo>', 'AllUsers': [1507]},
#  {'_id': '<git><control-de-versiones>', 'AllUsers': [75]},
#  {'_id': '<django><sql><postgresql>', 'AllUsers': [371]},
#  {'_id': '<ios><objective-c><uiwebview><ios8>', 'AllUsers': [965]},
#  {'_id': '<azure>', 'AllUsers': [348]},
#  {'_id': '<xaml><uwp>', 'AllUsers': [2230]},
#  {'_id': '<javascript><comparaciones>', 'AllUsers': [517]},
#  {'_id': '<wolfram-mathematica>', 'AllUsers': [1623]},
#  {'_id': '<python><matemáticas>', 'AllUsers': [2004]},
#  {'_id': '<java><oracle><base64>', 'AllUsers': [1555]},
#  {'_id': '<git><git-commit><github><git-push><git-fork>', 'AllUsers': [342]},
#  {'_id': '<bash><linux>', 'AllUsers': [100, 729]},
#  {'_id': '<windows>', 'AllUsers': [1119]},
#  {'_id': '<java><android><admob>', 'AllUsers': [2163]},
#  {'_id': '<c#>', 'AllUsers': [2325, 23, 25, 72]},
#  {'_id': '<oracle><oracle-11g><sqlfiddle>', 'AllUsers': [342]},
#  {'_id': '<java><android><android-layout>', 'AllUsers': [1870]},
#  {'_id': '<java><android>', 'AllUsers': [1943, 1958, 2034, 1870, 1914, 608]},
#  {'_id': '<eclipse><ftp>', 'AllUsers': [2387]},
#  {'_id': '<hilos>', 'AllUsers': [870]},
#  {'_id': '<mongodb><nosql>', 'AllUsers': [1725, 2133]},
#  {'_id': '<netbeans>', 'AllUsers': [342]},
#  {'_id': '<android-studio><ubuntu><java>', 'AllUsers': [2172]},
#  {'_id': '<javascript><html><vistas><backbone>', 'AllUsers': [1037]},
#  {'_id': '<paso-por-valor><paso-por-referencia><lenguaje-agnóstico>',
#   'AllUsers': []},
#  {'_id': '<validación><formularios><html5>', 'AllUsers': [100]},
#  {'_id': '<api><ruby><http><post>', 'AllUsers': [29]},
#  {'_id': '<clojure>', 'AllUsers': [252]},
#  {'_id': '<java><jpa>', 'AllUsers': [400]},
#  {'_id': '<c++><makefile>', 'AllUsers': [301]},
#  {'_id': '<plugin><wordpress>', 'AllUsers': [533]},
#  {'_id': '<c><hilos>', 'AllUsers': [187]},
#  {'_id': '<seo>', 'AllUsers': [2208]},
#  {'_id': '<java><loops><operador-incremento>', 'AllUsers': [517]},
#  {'_id': '<javascript><json><string>', 'AllUsers': [2004]},
#  {'_id': '<ide><sublimetext><sublimetext3>', 'AllUsers': [292]},
#  {'_id': '<java><base-de-datos><archivo-de-propiedades>', 'AllUsers': [2293]},
#  {'_id': '<java><dukescript>', 'AllUsers': [342]},
#  {'_id': '<java>', 'AllUsers': [301, 1943, 517, 260, 342]},
#  {'_id': '<swift>', 'AllUsers': [1881]},
#  {'_id': '<bash><archivo>', 'AllUsers': [83]},
#  {'_id': '<pouchdb>', 'AllUsers': [22]},
#  {'_id': '<nodejs><post><permisos>', 'AllUsers': [2327]},
#  {'_id': '<vb.net>', 'AllUsers': [2531]},
#  {'_id': '<ubuntu><nodejs><ec2><npm>', 'AllUsers': [631]},
#  {'_id': '<perl><booleano><conversión-de-tipos>', 'AllUsers': [22]},
#  {'_id': '<ios><xcode><objective-c>', 'AllUsers': [1499]},
#  {'_id': '<sql-server><asp.net-mvc-5>', 'AllUsers': [1203]},
#  {'_id': '<c#><asp.net-mvc-5><razor>', 'AllUsers': [225, 1168]},
#  {'_id': '<javascript><angularjs>', 'AllUsers': [23, 1505, 2256, 2509, 1407]},
#  {'_id': '<javascript><jquery><api><google-drive>', 'AllUsers': [1947]},
#  {'_id': '<python><numpy><array>', 'AllUsers': [74]},
#  {'_id': '<haskell>', 'AllUsers': [100]},
#  {'_id': '<nginx><logrotate><configuración>', 'AllUsers': [100]},
#  {'_id': '<visual-studio><nuget>', 'AllUsers': [1839]},
#  {'_id': '<ssms>', 'AllUsers': [1905]},
#  {'_id': '<ios><xcode><swift><swift2>', 'AllUsers': [1527]},
#  {'_id': '<meteor><cuenta-usuario>', 'AllUsers': [292]},
#  {'_id': '<jsf><primefaces>', 'AllUsers': [1948]},
#  {'_id': '<latex>', 'AllUsers': [271]},
#  {'_id': '<visual-studio><azure><visual-studio-2015>', 'AllUsers': [398]},
#  {'_id': '<linux><c>', 'AllUsers': [2013]},
#  {'_id': '<.net><regex><vb.net>', 'AllUsers': [745]},
#  {'_id': '<ios><xcode><swift>', 'AllUsers': [1527]},
#  {'_id': '<c++><java><rendimiento><optimización>', 'AllUsers': [301]},
#  {'_id': '<javascript><bookmarklet><gmail>', 'AllUsers': [65]},
#  {'_id': '<angularjs>', 'AllUsers': [1996]},
#  {'_id': '<javascript><java><jquery>', 'AllUsers': [400]},
#  {'_id': '<javascript><jquery><thymeleaf>', 'AllUsers': [400]},
#  {'_id': '<python><matplotlib><pyqt5><embebido>', 'AllUsers': [801]},
#  {'_id': '<java><android><json>', 'AllUsers': [1958]},
#  {'_id': '<java><thymeleaf>', 'AllUsers': [400]},
#  {'_id': '<algoritmos><lenguaje-agnóstico><loops><condiciones>',
#   'AllUsers': [517]},
#  {'_id': '<java><spring><spring-mvc>', 'AllUsers': []},
#  {'_id': '<jvm><java>', 'AllUsers': [264]},
#  {'_id': '<html>', 'AllUsers': [342]},
#  {'_id': '<javascript><android><reactjs><react-native>', 'AllUsers': [27]},
#  {'_id': '<javascript><ecmascript-2015>', 'AllUsers': [729]},
#  {'_id': '<yii>', 'AllUsers': [1365]},
#  {'_id': '<python><django><ordenamiento>', 'AllUsers': [535]},
#  {'_id': '<python><python-3.x><pdf><reportlab>', 'AllUsers': [100]},
#  {'_id': '<laravel><laravel-5>', 'AllUsers': [360]},
#  {'_id': '<c#><unity3d>', 'AllUsers': [342, 2257]},
#  {'_id': '<r><rodbc>', 'AllUsers': [1543]},
#  {'_id': '<c><manejo-de-memoria>', 'AllUsers': [187]},
#  {'_id': '<javascript><angularjs><ajax>', 'AllUsers': [23]},
#  {'_id': '<php><mysql><mysqli>', 'AllUsers': [1746]},
#  {'_id': '<java><sql><oracle><jdbc>', 'AllUsers': [342]},
#  {'_id': '<delphi>', 'AllUsers': [21]},
#  {'_id': '<r><ggplot2>', 'AllUsers': [271]},
#  {'_id': '<python><python-3.x><datetime>', 'AllUsers': [100]},
#  {'_id': '<python><python-2.7><funciones>', 'AllUsers': [100]},
#  {'_id': '<mercurial><control-de-versiones>', 'AllUsers': [100]},
#  {'_id': '<css><google-forms>', 'AllUsers': [65]},
#  {'_id': '<angularjs><json><http><post>', 'AllUsers': [2136]},
#  {'_id': '<html5><css><bootstrap><css3>', 'AllUsers': [225]},
#  {'_id': '<javascript><.net><signalr><real-time>', 'AllUsers': [547]},
#  {'_id': '<php><joomla3>', 'AllUsers': [729]},
#  {'_id': '<c++><c++11>', 'AllUsers': [24, 25, 463]},
#  {'_id': '<ios><objective-c>', 'AllUsers': [403, 1499]},
#  {'_id': '<xml>', 'AllUsers': [1776]},
#  {'_id': '<java><hilos><multitasking>', 'AllUsers': [1943]},
#  {'_id': '<html><html5><css><css3>', 'AllUsers': [2295]},
#  {'_id': '<c#><ofuscación>', 'AllUsers': [1941]},
#  {'_id': '<c#><xaml><windows-forms><wpf>', 'AllUsers': [2238]},
#  {'_id': '<sql><oracle><oracle-10g>', 'AllUsers': [21]},
#  {'_id': '<android><android-softkeyboard>', 'AllUsers': [305]},
#  {'_id': '<asp.net><visual-studio-2010>', 'AllUsers': [1399]},
#  {'_id': '<go>', 'AllUsers': [22]},
#  {'_id': '<ios><swift2><xcode>', 'AllUsers': [1499]},
#  {'_id': '<java><hibernate><sqlite3><sqlite>', 'AllUsers': [1972]},
#  {'_id': '<spring><spring-roo><gvnix>', 'AllUsers': [701]},
#  {'_id': '<javascript><jquery><jquery-datepicker>', 'AllUsers': [2027]},
#  {'_id': '<sql><sql-server>', 'AllUsers': [77]},
#  {'_id': '<c++><casting>', 'AllUsers': [24]},
#  {'_id': '<php><ajax><laravel><laravel-5>', 'AllUsers': [73]},
#  {'_id': '<javascript><validación><email><regex>', 'AllUsers': [127]},
#  {'_id': '<java><android><navigationview>', 'AllUsers': [608]},
#  {'_id': '<java><paso-por-valor><paso-por-referencia>', 'AllUsers': [301]},
#  {'_id': '<conda>', 'AllUsers': [353]},
#  {'_id': '<javascript><nodejs>', 'AllUsers': [22, 149]},
#  {'_id': '<javascript><html><xhtml>', 'AllUsers': [120]},
#  {'_id': '<php><array>', 'AllUsers': [127]},
#  {'_id': '<java><archivo-de-propiedades><i18n>', 'AllUsers': [342]},
#  {'_id': '<javascript><jquery><eventos>', 'AllUsers': [22]},
#  {'_id': '<sequelize.js><pruebas-unitarias>', 'AllUsers': [345]},
#  {'_id': '<git><git-push>', 'AllUsers': [555]},
#  {'_id': '<java><string><java-8><java-stream>', 'AllUsers': [517]},
#  {'_id': '<java><try-catch>', 'AllUsers': [261]},
#  {'_id': '<jquery><html><youtube>', 'AllUsers': [238]},
#  {'_id': '<javascript><json><angularjs>', 'AllUsers': [1839]},
#  {'_id': '<linux><grep>', 'AllUsers': [2013]},
#  {'_id': '<ios><swift2>', 'AllUsers': [1784]},
#  {'_id': '<python><conda>', 'AllUsers': [353]},
#  {'_id': '<java><netbeans><plugin>', 'AllUsers': [342]},
#  {'_id': '<dns><iana>', 'AllUsers': [307]},
#  {'_id': '<python><web2py>', 'AllUsers': [908]},
#  {'_id': '<android><google-newsstand-producer><rss>', 'AllUsers': [95]},
#  {'_id': '<javascript><html><json><knockoutjs>', 'AllUsers': [342]},
#  {'_id': '<c++><visual-studio-2010>', 'AllUsers': [2236]},
#  {'_id': '<linux><debian><ntfs>', 'AllUsers': [271]},
#  {'_id': '<java><android><optimización><android-sqlite>', 'AllUsers': [206]},
#  {'_id': '<ios><jquery><cordova>', 'AllUsers': [239]},
#  {'_id': '<java><spring><spring-mvc><spring-security>', 'AllUsers': [2288]},
#  {'_id': '<netbeans><maven>', 'AllUsers': [342]},
#  {'_id': '<c++><array>', 'AllUsers': [25]},
#  {'_id': '<php><sql>', 'AllUsers': [2392]},
#  {'_id': '<mysql><sql>', 'AllUsers': [90, 660]},
#  {'_id': '<ios><xcode><swift><ios8>', 'AllUsers': [1527]},
#  {'_id': '<c++><qt>', 'AllUsers': [463]},
#  {'_id': '<java><conversión-de-tipos><tipos>', 'AllUsers': [2027]},
#  {'_id': '<mysql><windows><delphi>', 'AllUsers': [1184]},
#  {'_id': '<mysql><datetime><timestamp>', 'AllUsers': [21]},
#  {'_id': '<android><android-layout><unidades-de-medición>', 'AllUsers': [305]},
#  {'_id': '<git><visual-studio><nodejs><azure>', 'AllUsers': [398]},
#  {'_id': '<python><django><python-3.x><django-models>',
#   'AllUsers': [1270, 1005]},
#  {'_id': '<python><string><ordenamiento>', 'AllUsers': [2235]},
#  {'_id': '<ruby-on-rails><ruby><vistas>', 'AllUsers': [29]},
#  {'_id': '<jquery><django><django-models><ajax>', 'AllUsers': [2394]},
#  {'_id': '<array><perl>', 'AllUsers': [22]},
#  {'_id': '<magento2>', 'AllUsers': [729]},
#  {'_id': '<php><doctrine><doctrine2>', 'AllUsers': [360]},
#  {'_id': '<c++><string><tokens>', 'AllUsers': [24]},
#  {'_id': '<ios><objective-c><swift>', 'AllUsers': [270]},
#  {'_id': '<android><arduino><socket><delphi><tcpip>', 'AllUsers': [21]},
#  {'_id': '<java><bigdecimal><redondeo><double>', 'AllUsers': [517]},
#  {'_id': '<django><api><djangorestframework><permisos>', 'AllUsers': [901]},
#  {'_id': '<html><formularios>', 'AllUsers': [2224]},
#  {'_id': '<ruby-on-rails>', 'AllUsers': [2349]},
#  {'_id': '<java><c++><punteros>', 'AllUsers': [301]},
#  {'_id': '<ios>', 'AllUsers': [233]},
#  {'_id': '<php><laravel-5>', 'AllUsers': [1545]},
#  {'_id': '<javascript><json><xml>', 'AllUsers': [1839]},
#  {'_id': '<java><clase>', 'AllUsers': [301]},
#  {'_id': '<archivo><unix><grep><ascii>', 'AllUsers': [83]},
#  {'_id': '<c#><asp.net-web-api><automapper>', 'AllUsers': [1188]},
#  {'_id': '<python><python-2.7>', 'AllUsers': [870, 2152, 2338, 100]},
#  {'_id': '<python><pip><pillow>', 'AllUsers': [783]},
#  {'_id': '<perl><tipos><booleano>', 'AllUsers': [288]},
#  {'_id': '<css><html5><css3><3d><importación>', 'AllUsers': [342]},
#  {'_id': '<string><c#>', 'AllUsers': [149]},
#  {'_id': '<python><yield>', 'AllUsers': [74]},
#  {'_id': '<javascript><momentjs><underscorejs>', 'AllUsers': [636]},
#  {'_id': '<oracle-10g><hql><jpa><seam>', 'AllUsers': [342]},
#  {'_id': '<javascript><html><google-maps><google-chrome>', 'AllUsers': [2004]},
#  {'_id': '<c#><motor-de-juego><unity3d><2d>', 'AllUsers': [2257]},
#  {'_id': '<javascript><html>', 'AllUsers': [729, 1788]},
#  {'_id': '<python><imagen>', 'AllUsers': [389]},
#  {'_id': '<git><github>', 'AllUsers': [2013]},
#  {'_id': '<genexus><devices>', 'AllUsers': [722]},
#  {'_id': '<oracle><oracle-11g>', 'AllUsers': [342]},
#  {'_id': '<google-hoja-de-cálculo><formulas><formato-condicional>',
#   'AllUsers': [1184]},
#  {'_id': '<programación-funcional><haskell><estructuras-de-datos>',
#   'AllUsers': [302]},
#  {'_id': '<javascript><clausuras>', 'AllUsers': [965]},
#  {'_id': '<sql><sql-server><tsql>', 'AllUsers': [2256]},
#  {'_id': '<java><json><gson>', 'AllUsers': [143]},
#  {'_id': '<javascript><sandbox><seguridad>', 'AllUsers': [22]},
#  {'_id': '<javascript><knockoutjs>', 'AllUsers': [35]},
#  {'_id': '<javascript><kendoui><knockoutjs>', 'AllUsers': [35]},
#  {'_id': '<wpf><xaml>', 'AllUsers': [92]},
#  {'_id': '<c#><jquery><ajax><asp.net-mvc-5><asp.net-mvc>', 'AllUsers': [629]},
#  {'_id': '<javascript><google-apps-script><google-hoja-de-cálculo><google-forms>',
#   'AllUsers': [65]},
#  {'_id': '<html5><css3><bootstrap><wordpress>', 'AllUsers': [1389]},
#  {'_id': '<licencias><código-abierto>', 'AllUsers': [25]},
#  {'_id': '<javascript><jquery><html>', 'AllUsers': [517, 2366]},
#  {'_id': '<python>', 'AllUsers': [1575, 2234, 100]},
#  {'_id': '<html><xpath>', 'AllUsers': [729]},
#  {'_id': '<javascript><android><ajax><cordova><jquery-mobile>',
#   'AllUsers': [2041]},
#  {'_id': '<javascript><ember.js>', 'AllUsers': [430]},
#  {'_id': '<oracle><sqlfiddle>', 'AllUsers': [342]},
#  {'_id': '<css>', 'AllUsers': [342]},
#  {'_id': '<perl><matrices-asociativas><ordenamiento>', 'AllUsers': [288]},
#  {'_id': '<javascript><jquery><typescript>', 'AllUsers': [629]},
#  {'_id': '<javascript><php><regex>', 'AllUsers': [729]},
#  {'_id': '<c#><sql-server><windows-forms>', 'AllUsers': [531]},
#  {'_id': '<python><django><django-models><users-roles>', 'AllUsers': [1005]},
#  {'_id': '<matemáticas><coma-flotante><lenguaje-agnóstico>',
#   'AllUsers': [416]},
#  {'_id': '<java><firebird>', 'AllUsers': [1687]},
#  {'_id': '<javascript><html><css>', 'AllUsers': [729]},
#  {'_id': '<android><cordova><ionic>', 'AllUsers': [100]},
#  {'_id': '<git><git-commit>', 'AllUsers': [83, 1943, 260, 299]},
#  {'_id': '<go><tipos>', 'AllUsers': [22]},
#  {'_id': '<java><android><bitmap>', 'AllUsers': [846]},
#  {'_id': '<unity3d>', 'AllUsers': [342]},
#  {'_id': '<linux><vpn>', 'AllUsers': [1303]},
#  {'_id': '<jquery><vb.net>', 'AllUsers': [1399]},
#  {'_id': '<java><android><linux><windows>', 'AllUsers': [2379]},
#  {'_id': '<asp.net><asp.net-mvc><librería><bower>', 'AllUsers': [35]},
#  {'_id': '<vpn><windows>', 'AllUsers': [813]},
#  {'_id': '<bash><linux><shell><sed><awk>', 'AllUsers': [83]},
#  {'_id': '<python><django>', 'AllUsers': [816, 353, 1005, 100]},
#  {'_id': '<sql><oracle>', 'AllUsers': [264, 1184]},
#  {'_id': '<python><linux><pip><ubuntu><python-2.7>', 'AllUsers': [100]},
#  {'_id': '<reactjs>', 'AllUsers': [75]},
#  {'_id': '<python><punteros>', 'AllUsers': [389]},
#  {'_id': '<.net><clickonce><deployment>', 'AllUsers': []},
#  {'_id': '<php><sql-server>', 'AllUsers': [1914]},
#  {'_id': '<java><alfresco>', 'AllUsers': [400]},
#  {'_id': '<php><poo>', 'AllUsers': [659]},
#  {'_id': '<directorioactivo><office365><smartcard><adfs>', 'AllUsers': [717]},
#  {'_id': '<json><mongodb><nosql>', 'AllUsers': [187]},
#  {'_id': '<abap>', 'AllUsers': [1098]},
#  {'_id': '<java><primefaces>', 'AllUsers': [2453]},
#  {'_id': '<pharo><smalltalk>', 'AllUsers': [302]},
#  {'_id': '<html><html5>', 'AllUsers': [271]},
#  {'_id': '<javascript>',
#   'AllUsers': [366,
#    2352,
#    430,
#    25,
#    399,
#    1547,
#    1839,
#    729,
#    2113,
#    342,
#    2346,
#    872,
#    2004]},
#  {'_id': '<c#><.net><entity-framework><asp.net-core><model-view-controller>',
#   'AllUsers': [298]},
#  {'_id': '<genexus>', 'AllUsers': [725, 728, 676, 2335]},
#  {'_id': '<json><asp.net-web-api>', 'AllUsers': [2256]},
#  {'_id': '<javascript><poo>', 'AllUsers': [729]},
#  {'_id': '<c#><uwp>', 'AllUsers': [2230]},
#  {'_id': '<git><git-merge>', 'AllUsers': [555]},
#  {'_id': '<php><laravel>', 'AllUsers': [2087]},
#  {'_id': '<python><django><python-3.x><celery>', 'AllUsers': [100]},
#  {'_id': '<mysql><phpmyadmin>', 'AllUsers': [1007]},
#  {'_id': '<python><python-2.7><lista>', 'AllUsers': [1965]},
#  {'_id': '<python><python-3.x>', 'AllUsers': [302, 292]},
#  {'_id': '<java><hibernate>', 'AllUsers': [608]},
#  {'_id': '<haskell><lista>', 'AllUsers': [100]},
#  {'_id': '<javascript><google-apps-script><google-hoja-de-cálculo><google-forms><google-documentos>',
#   'AllUsers': [65]},
#  {'_id': '<c#><asp.net-mvc-5><razor><asp.net-mvc>', 'AllUsers': [225]},
#  {'_id': '<c++>', 'AllUsers': [1997, 24, 301, 463]},
#  {'_id': '<raku>', 'AllUsers': [632]},
#  {'_id': '<c#><conversión-de-tipos><tipos>', 'AllUsers': [2027]},
#  {'_id': '<javascript><nodejs><depuración>', 'AllUsers': [187]},
#  {'_id': '<java><soap><struts>', 'AllUsers': [417]},
#  {'_id': '<python><python-2.7><python-3.x>', 'AllUsers': [2540]},
#  {'_id': '<javascript><array>', 'AllUsers': [729, 100, 517]},
#  {'_id': '<c++><string>', 'AllUsers': [24]},
#  {'_id': '<ios><xcode>', 'AllUsers': [233, 37]},
#  {'_id': '<javascript><array><object>', 'AllUsers': [132]},
#  {'_id': '<python><variables>', 'AllUsers': [218]},
#  {'_id': '<javascript><facebook><internet-explorer-11>', 'AllUsers': [1583]},
#  {'_id': '<css><jsfiddle><scss>', 'AllUsers': [342]},
#  {'_id': '<typescript>', 'AllUsers': [20]},
#  {'_id': '<java><excel><apache-poi>', 'AllUsers': [1809]},
#  {'_id': '<ios><formularios><objective-c>', 'AllUsers': [160]},
#  {'_id': '<python><macos>', 'AllUsers': [271]},
#  {'_id': '<mysql><sql><join>', 'AllUsers': [21]},
#  {'_id': '<html><css>', 'AllUsers': [260]},
#  {'_id': '<oracle><formularios><oracle-10g>', 'AllUsers': [1390]},
#  {'_id': '<javascript><jquery><asincronismo>', 'AllUsers': [100, 400]},
#  {'_id': '<java><localización>', 'AllUsers': [301]},
#  {'_id': '<swift><swift2>', 'AllUsers': [2282]},
#  {'_id': '<c#><reflexión>', 'AllUsers': [92]},
#  {'_id': '<.net><asp.net-web-api><asp.net>', 'AllUsers': [23]},
#  {'_id': '<c#><windows-forms>', 'AllUsers': [531, 2238, 1577, 1840]},
#  {'_id': '<php>', 'AllUsers': [2392, 729]},
#  {'_id': '<mysql><vagrant><puppet>', 'AllUsers': [399]},
#  {'_id': '<swift2>', 'AllUsers': [1513, 2137]},
#  {'_id': '<php><sql><mysql><phpmyadmin><mysqli>', 'AllUsers': [2262]},
#  {'_id': '<spring><hibernate><jpa><spring-mvc>', 'AllUsers': [2004]},
#  {'_id': '<android><php><json><mysql>', 'AllUsers': [2539]},
#  {'_id': '<c#><.net><asp.net><azure><azure-storage>', 'AllUsers': [1482]},
#  {'_id': '<mysql><python><base-de-datos>', 'AllUsers': [100]},
#  {'_id': '<java><jsf><java-ee>', 'AllUsers': [2357]},
#  {'_id': '<javascript><jasmine><momentjs>', 'AllUsers': [23]},
#  {'_id': '<java><apache-poi>', 'AllUsers': [1809]},
#  {'_id': '<java><io>', 'AllUsers': [2399]},
#  {'_id': '<tsql>', 'AllUsers': [1859]},
#  {'_id': '<mysql><java><spring><hibernate>', 'AllUsers': [187]},
#  {'_id': '<java><constructor><clase-abstracta><poo>', 'AllUsers': [187]},
#  {'_id': '<select2><yii><yiibooster><cache>', 'AllUsers': [1076]},
#  {'_id': '<oauth>', 'AllUsers': [2004]},
#  {'_id': '<git>', 'AllUsers': [555, 2027, 1798, 22, 25, 417, 399, 1914, 729]},
#  {'_id': '<soap><soapui><wcf><servicio>', 'AllUsers': [325]},
#  {'_id': '<typescript><aurelia.io><select2>', 'AllUsers': [629]},
#  {'_id': '<php><yii2><i18n>', 'AllUsers': [1055]},
#  {'_id': '<html5><bootstrap>', 'AllUsers': [1827]},
#  {'_id': '<sql><oracle><oracle-11g>', 'AllUsers': [1184]},
#  {'_id': '<c#><visual-studio>', 'AllUsers': [1092]},
#  {'_id': '<java><string><comparaciones>', 'AllUsers': [517]},
#  {'_id': '<java><android><android-intent><android-asynctask>',
#   'AllUsers': [206]},
#  {'_id': '<java><jersey><swagger>', 'AllUsers': [608]},
#  {'_id': '<c#><sharepoint><sharepoint-online>', 'AllUsers': [78]},
#  {'_id': '<python><archivo>', 'AllUsers': [100, 2152]},
#  {'_id': '<c#><wpf><xaml>', 'AllUsers': [92]},
#  {'_id': '<bash><shell>', 'AllUsers': [2222, 1965]},
#  {'_id': '<php><timestamp>', 'AllUsers': [132]},
#  {'_id': '<javascript><jquery><datatables>', 'AllUsers': [547]},
#  {'_id': '<android><android-auto>', 'AllUsers': [546]},
#  {'_id': '<java><postgresql>', 'AllUsers': [2019]},
#  {'_id': '<google-maps><angularjs><jasmine><karma-jasmine>', 'AllUsers': [23]},
#  {'_id': '<php><yii2>', 'AllUsers': [729]},
#  {'_id': '<bash><zsh>', 'AllUsers': [83]},
#  {'_id': '<api><nosql><couchdb>', 'AllUsers': [2186]},
#  {'_id': '<c#><.net>', 'AllUsers': [463, 2488, 2004]},
#  {'_id': '<django><django-models>', 'AllUsers': [1005]},
#  {'_id': '<javascript><jquery><asp.net-mvc-5>', 'AllUsers': [2366]},
#  {'_id': '<json><visual-studio><asp.net-core>', 'AllUsers': [211]},
#  {'_id': '<python><xml>', 'AllUsers': [2059]},
#  {'_id': '<excel><vba>', 'AllUsers': [749]},
#  {'_id': '<bash><verilog>', 'AllUsers': [389]},
#  {'_id': '<javascript><jquery><html><html5>', 'AllUsers': [250]},
#  {'_id': '<javascript><pdf><google-apps-script>', 'AllUsers': [1360]},
#  {'_id': '<vb.net><windows-forms>', 'AllUsers': [1168]},
#  {'_id': '<python><excepciones>', 'AllUsers': [100]},
#  {'_id': '<archivo><windows><consola><proceso>', 'AllUsers': [1184]},
#  {'_id': '<ruby-on-rails><rspec>', 'AllUsers': [631]},
#  {'_id': '<c++><c>', 'AllUsers': [24]},
#  {'_id': '<c++><constructor>', 'AllUsers': [301]},
#  {'_id': '<sql><ms-access-2010>', 'AllUsers': [120]},
#  {'_id': '<archivo><linux><rsync>', 'AllUsers': [632]},
#  {'_id': '<java><java-ee><ide>', 'AllUsers': [167]},
#  {'_id': '<javascript><jquery><json>', 'AllUsers': [731, 1839, 342]},
#  {'_id': '<javascript><jquery><html5>', 'AllUsers': [2367]},
#  {'_id': '<python><djangorestframework><django-models>', 'AllUsers': [1005]},
#  {'_id': '<sql><oracle-11g><sqlfiddle>', 'AllUsers': [1184]},
#  {'_id': '<c#><asp.net-mvc-5>', 'AllUsers': [2036]},
#  {'_id': '<javascript><jquery><dom>', 'AllUsers': [132]},
#  {'_id': '<archivo><fish><exists>', 'AllUsers': [302]},
#  {'_id': '<python><python-2.7><clase><método>', 'AllUsers': [100]},
#  {'_id': '<python><django><python-2.7>', 'AllUsers': [1274]},
#  {'_id': '<java><eclipse><depuración><jboss>', 'AllUsers': [342]},
#  {'_id': '<ios><swift><xcode><iphone>', 'AllUsers': [1527]},
#  {'_id': '<json><swift2>', 'AllUsers': [1913]},
#  {'_id': '<.net><entity-framework>', 'AllUsers': [921]},
#  {'_id': '<java><android><avd>', 'AllUsers': [1592]},
#  {'_id': '<javascript><jquery><angularjs>', 'AllUsers': [1505]},
#  {'_id': '<javascript><jquery>',
#   'AllUsers': [729, 2224, 21, 2238, 2156, 1839]},
#  {'_id': '<java><string><regex>', 'AllUsers': [517]},
#  {'_id': '<javascript><underscorejs>', 'AllUsers': [636]}]

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# ### EJ1: Obtener el resultado de documentos *verbosos* en donde se indique el texto `Body` de una pregunta así como el nombre del usuario que la formuló (`DisplayName`)

# %% [markdown]
# ### EJ2: Obtener las respuestas escritas en Enero de 2022 con un `Score` superior a 3

# %%
print("Eso es todo amigos!")
# Out:
# Eso es todo amigos!
